# %% [markdown]
# # Data and model testing

# %%
import os

# gets rid of irritating warnings
os.environ["TOKENIZERS_PARALLELISM"] = "false"

# %% [markdown]
# ## Data preprocessing and initial quality checking
#
# We will be using [booking.com reviews dataset](https://www.kaggle.com/datasets/jiashenliu/515k-hotel-reviews-data-in-europe?resource=download), with over 500 thousand reviews of hotels. They are either positive or negative, and we will focus on review sentiment. We have [hosted it on HuggingFace](https://huggingface.co/datasets/morgul10/booking_reviews), with just the relevant columns.
#
# We will start with loading the data and initial checks - a **smoke test** of the data. Aim is to understand our dataset, and to detect obvious and serious problems. It is always a necessary process in ML.
#
# Most basic checks, which should always be performed, are:
# - data length
# - column types
# - example rows
# - exact duplicates check
# - labels distributions (for supervised problems)
# - more specific checks depending on the modality, e.g. text lengths distribution in NLP

# %%
import matplotlib.pyplot as plt
import pandas as pd

from datasets import load_dataset


df_raw = load_dataset("morgul10/booking_reviews")["train"].to_pandas()
df_neg = df_raw["Negative_Review"].str.strip()
df_pos = df_raw["Positive_Review"].str.strip()

# %%
print("Total data length:", len(df_raw))
print("Negative reviews:", len(df_neg))
print("Positive reviews:", len(df_pos))
# Out:
# Total data length: 515738
# Negative reviews: 515738
# Positive reviews: 515738

# %%
print("Data types:")
df_raw.dtypes
# Out:
# Data types:
# Negative_Review    object
# Positive_Review    object
# dtype: object

# %%
print("First rows:")
display(df_raw.head(10))
# Out:
# First rows:
#                                      Negative_Review  \
# 0   I am so angry that i made this post available...
# 1                                        No Negative
# 2   Rooms are nice but for elderly a bit difficul...
# 3   My room was dirty and I was afraid to walk ba...
# 4   You When I booked with your company on line y...
# 5   Backyard of the hotel is total mess shouldn t...
# 6   Cleaner did not change our sheet and duvet ev...
# 7   Apart from the price for the brekfast Everyth...
# 8   Even though the pictures show very clean room...
# 9   The aircondition makes so much noise and its ...
#
#                                      Positive_Review
# 0   Only the park outside of the hotel was beauti...
# 1   No real complaints the hotel was great great ...
# 2   Location was good and staff were ok It is cut...
# 3   Great location in nice surroundings the bar a...
# 4    Amazing location and building Romantic setting
# 5   Good restaurant with modern design great chil...
# 6   The room is spacious and bright The hotel is ...
# 7   Good location Set in a lovely park friendly s...
# 8                                        No Positive
# 9   The room was big enough and the bed is good T...

# %%
print("Last rows:")
display(df_raw.tail(10))
# Out:
# Last rows:
#                                           Negative_Review  \
# 515728                                         Everything
# 515729                                        No Negative
# 515730   no free parking the room was in another build...
# 515731   No parking Public parking garage is 15 Euro p...
# 515732                                        No Negative
# 515733   no trolly or staff to help you take the lugga...
# 515734           The hotel looks like 3 but surely not 4
# 515735   The ac was useless It was a hot week in vienn...
# 515736                                        No Negative
# 515737       I was in 3rd floor It didn t work Free Wife
#
#                                           Positive_Review
# 515728                                            Nothing
# 515729   The breakfast was excelent lots of fress frui...
# 515730                                         large room
# 515731                                     Good breakfast
# 515732   helpful staff allowed me to check in early as...
# 515733                                           location
# 515734      Breakfast was ok and we got earlier check in
# 515735                                        No Positive
# 515736   The rooms are enormous and really comfortable...
# 515737                               staff was very kind

# %%
df_neg.str.len().plot.hist(title="Negative reviews lengths")
# Out:
# <Axes: title={'center': 'Negative reviews lengths'}, ylabel='Frequency'>

# %%
df_pos.str.len().plot.hist(title="Positive reviews lengths")
# Out:
# <Axes: title={'center': 'Positive reviews lengths'}, ylabel='Frequency'>

# %% [markdown]
# As you can see, the data contains quite a few "No Negatives" and "No Positive" rows. This is a widespread problem with "empty" rows, which are not really empty. They can take a form of:
# - default text, like we have here (frequent in automated forms, data from web scraping etc.)
# - empty string instead of NULL
# - deleted rows, but only marked with "deleted" column (frequent in data warehouses)
#
# Those problems can also crop up during inference (e.g., empty text), and should be handled properly.
#
# This is a particular instance of **duplicate data** problem, which is surprisingly common. Another reason may be that people writing texts don't care, e.g. input generic answers like "ok" or "everything". This biases the model, essentially putting more weights on those texts. Worse, they can have different labels, which introduces strong noise.
#
# Let's see how frequent is this problem.

# %% [markdown]
# ### Exercise 1 (1 point)
#
# Check the percentage of 20 most common text duplicates. This can be achieved with Pandas code conceptually similar to a combination of GROUP BY and COUNT aggregation. Check it:
# - in positive and negative subsets
# - for the whole dataset

# %%
df_raw["Negative_Review"].value_counts().head(20)
# Out:
# Negative_Review
# No Negative         127890
#  Nothing             14295
#  Nothing              4236
#  nothing              2225
#  N A                  1037
#  None                  984
#                        849
#  N a                   509
#  Breakfast             407
#  Small room            373
#  Location              368
#  Everything            326
#  All good              318
#  Nothing really        316
#  none                  302
#  nothing               283
#  No complaints         274
#  Price                 260
#  Nothing really        254
#  Nil                   247
# Name: count, dtype: int64

# %%
df_raw["Positive_Review"].value_counts().head(20)
# Out:
# Positive_Review
# No Positive            35946
#  Location               9222
#  Everything             2284
#  location               1677
#  Nothing                1243
#  The location           1126
#  Great location         1047
#  Good location           927
#  Location                915
#  Everything              613
#  Breakfast               608
#  Friendly staff          515
#  Staff                   453
#  Excellent location      392
#  Great location          372
#  Location and staff      333
#  everything              319
#  Good location           276
#  Nothing                 225
#  Comfy bed               222
# Name: count, dtype: int64

# %%
df_raw.value_counts(subset=["Negative_Review", "Positive_Review"]).head(20)
# Out:
# Negative_Review  Positive_Review
# No Negative       Location              1009
#  Nothing          Everything             940
# No Negative       Everything             593
#                   Great location         256
#                   Everything             204
#                   location               200
#  Nothing          Location               193
#  Nothing          Everything             150
# No Negative       Location               133
#                  No Positive             127
#  Everything       Nothing                127
#  nothing          everything             123
# No Negative       Great location         111
#                   Excellent location     106
#                   Good location          103
#                   Friendly staff          86
#                   The location            85
#                   everything              84
#                   Breakfast               78
#  Breakfast       No Positive              76
# Name: count, dtype: int64

# %% [markdown]
# ### Manual data cleaning

# %% [markdown]
# Imagine training (and testing!) a model on data, where about 25% of negative class is duplicated, or has useless values like "none". Not a good idea, so we will remove those duplicates simply by using a case-insensitive regular expression. We will also remove words like "breakfast" or "location," which do not discriminate at all between positive and negative sentiment.

# %%
to_remove = [
    "No Negative", "No Positive", "nothing", "nothing really", "none", "n a", "na",
    "everything", "location", "the location", "breakfast", "the breakfast", "staff",
]
to_remove = [f"^{word}$" for word in to_remove]
to_remove = "|".join(to_remove)
to_remove
# Out:
# '^No Negative$|^No Positive$|^nothing$|^nothing really$|^none$|^n a$|^na$|^everything$|^location$|^the location$|^breakfast$|^the breakfast$|^staff$'

# %% [markdown]
# We will also perform two common cleaning steps: deduplication and removing empty strings. We can safely assume that people are lazy and write short, generic reviews, so there will be quite a few duplicates even after removing the most obvious cases.

# %%
df_neg_filtered = df_neg[~df_neg.str.contains(to_remove, case=False, na=True, regex=True)]
df_pos_filtered = df_pos[~df_pos.str.contains(to_remove, case=False, na=True, regex=True)]

# empty strings removal
df_neg_filtered = df_neg_filtered[df_neg_filtered.str.len() > 0]
df_pos_filtered = df_pos_filtered[df_pos_filtered.str.len() > 0]

df_neg_filtered = df_neg_filtered.reset_index(drop=True)
df_pos_filtered = df_pos_filtered.reset_index(drop=True)

df_neg_filtered = df_neg_filtered.to_frame().rename(columns={"Negative_Review": "text"})
df_pos_filtered = df_pos_filtered.to_frame().rename(columns={"Positive_Review": "text"})

df_neg_filtered["label"] = 0
df_pos_filtered["label"] = 1

print("Negative samples after filtering:", len(df_neg_filtered))
print("Positive samples after filtering:", len(df_pos_filtered))

df_all = pd.concat([df_neg_filtered, df_pos_filtered], ignore_index=True)
df_all = df_all.drop_duplicates(ignore_index=True)
# Out:
# Negative samples after filtering: 359750
# Positive samples after filtering: 459388

# %% [markdown]
# Lastly, we have quite a lot of data, so we'll randomly subsample it. We will use stratification, so that the label distribution will be the same after sampling.
#
# **Modify this** depending on your hardware. Very good GPU should handle up to ~100k samples, medium-grade GPU about ~10-50k, and CPU about 5k. The more samples you process, the better the results will be.

# %%
from sklearn.utils import resample


df = resample(df_all, replace=False, n_samples=100000, random_state=0, stratify=df_all["label"])
df = df.reset_index(drop=True)
df
# Out:
#                                                     text  label
# 0      Rather slow service at reception bathroom floo...      0
# 1                                      Location AND WIFI      1
# 2                                  Far from tram station      0
# 3               Location to tube station Comfy bed Roomy      1
# 4      Lovely and spotless hotel with an old world ch...      1
# ...                                                  ...    ...
# 99995  Excellent breakfast buffet very handy for tram...      1
# 99996  Easy to get everywhere Very good restaurant ne...      1
# 99997  Excellent location and staff Beautiful authent...      1
# 99998  Our room was just big enough for the bed but w...      0
# 99999  Bit hectic at breakfast Had to ask for tea and...      0
#
# [100000 rows x 2 columns]

# %% [markdown]
# ## CleanLab blackbox testing
#
# [CleanLab library](https://github.com/cleanlab/cleanlab) aims to provide a blackbox, dead simple to use solution to ensure data quality. It can clean both data and labels, and works for any models. It is based on the framework of **confident learning (CL)**, originally created for detecting problems with data annotations.
#
# The main idea is as follows. A reasonably good model trained on the data should be very confident about properly annotated texts, and uncertain about ambiguous or incorrectly annotated texts. This is measured by predicted class probabilities. There are, of course, more details (e.g., class-conditioning, distinguishing model and data errors), but the general idea is really simple, and works with any data modality. It can not only detect errors, but also fix them. If another label is predicted with very high confidence, there is a high chance it's the correct one.
#
# ![flowchart.png](attachment:17e1aba2-573a-4693-a4a8-6d3f5ee8883a.png)
#
# Researchers in confidence learning, and creators of CleanLab, used this methodology in paper ["Pervasive label errors in test sets destabilize machine learning benchmarks" C.G. Northcutt et al](https://arxiv.org/abs/2103.14749). They showed that in popular text and image benchmarking datasets, up to 10% of labels are incorrect.
#
# We will take a similar approach to test our dataset. To avoid a chicken-and-egg problem (we don't have a model yet, but we need model probabilities), we need the **initial model**. A simple, yet effective approach is using a pretrained embedding model, combined with a linear classifier. This method is equivalent to freezing weights and training just the classifier head. Both embeddings and probability predictions are then used by CleanLab to detect problems.
#
# For text classification, the workflow recommended by [HuggingFace Open-Source AI Cookbook](https://huggingface.co/learn/cookbook/en/issues_in_text_dataset) is:
# 1. Compute text embeddings with a pretrained Sentence Transformer for feature extraction
# 2. Train logistic regression with cross-validation
# 3. Gather predicted probabilities (model confidence scores) for validation sets
# 4. Use CleanLab using this data
#
# Bonus: we originally detected some problems with duplicates in this dataset also by using CleanLab.

# %% [markdown]
# ### Exercise 2 (1 point)
#
# Implement the `get_initial_model_data()` function:
# 1. Compute text embeddings with [sentence-transformers](https://sbert.net/docs/sentence_transformer/pretrained_models.html) and `all-MiniLM-L6-v2` model.
# 2. Create `LogisticRegression` object
# 3. Train logistic regression and get probability predictions using `cross_val_predict()`. Note that it requires explicitly specifying that `predict_proba()` method should be used, in order to return probabilities, rather than 0/1 labels.

# %%
import joblib
import numpy as np
from sentence_transformers import SentenceTransformer
from sklearn.linear_model import LogisticRegression
from sklearn.model_selection import cross_val_predict


def get_initial_model_data(texts: np.ndarray, labels: np.ndarray) -> tuple[np.ndarray, np.ndarray]:
    model = SentenceTransformer("all-MiniLM-L6-v2")
    embeddings = model.encode(texts, show_progress_bar=True, convert_to_numpy=True)
    clf = LogisticRegression(max_iter=1000, random_state=0)
    pred_probs = cross_val_predict(
        clf,
        embeddings,
        labels,
        cv=5,
        method="predict_proba",
        n_jobs=joblib.cpu_count(only_physical_cores=True),
    )

    return embeddings, pred_probs

# %% [markdown]
# #### Verification

# %%
texts = df["text"].values
labels = df["label"].values

embeddings, pred_probs = get_initial_model_data(texts, labels)
# Out:
# modules.json:   0%|          | 0.00/349 [00:00<?, ?B/s]
# config_sentence_transformers.json:   0%|          | 0.00/116 [00:00<?, ?B/s]
# README.md: 0.00B [00:00, ?B/s]
# sentence_bert_config.json:   0%|          | 0.00/53.0 [00:00<?, ?B/s]
# config.json:   0%|          | 0.00/612 [00:00<?, ?B/s]
# model.safetensors:   0%|          | 0.00/90.9M [00:00<?, ?B/s]
# tokenizer_config.json:   0%|          | 0.00/350 [00:00<?, ?B/s]
# vocab.txt: 0.00B [00:00, ?B/s]
# tokenizer.json: 0.00B [00:00, ?B/s]
# special_tokens_map.json:   0%|          | 0.00/112 [00:00<?, ?B/s]
# config.json:   0%|          | 0.00/190 [00:00<?, ?B/s]
# Batches:   0%|          | 0/3125 [00:00<?, ?it/s]

# %% [markdown]
# And now, we can use the CleanLab with the obtained embeddings and probability predictions.

# %%
from cleanlab import Datalab


data_dict = {"texts": texts, "labels": labels}
lab = Datalab(data_dict, label_name="labels", task="classification")
lab.find_issues(pred_probs=pred_probs, features=embeddings)
lab.report()
# Out:
# Finding null issues ...
# Finding label issues ...
# Finding outlier issues ...
# Finding near_duplicate issues ...
# Finding non_iid issues ...
# Finding class_imbalance issues ...
# Finding underperforming_group issues ...
#
# Audit complete. 4584 issues found in the dataset.
# Dataset Information: num_examples: 100000, num_classes: 2
#
# Here is a summary of various issues found in your data:
#
#     issue_type  num_issues
#          label        2136
# near_duplicate        1906
#        outlier         542
#
# Learn about each issue: https://docs.cleanlab.ai/stable/cleanlab/datalab/guide/issue_type_description.html
# See which examples in your dataset exhibit each issue via: `datalab.get_issues(<ISSUE_NAME>)`
#
# Data indices corresponding to top examples of each issue are shown below.
#
#
# ----------------------- label issues -----------------------
#
# About this issue:
# 	Examples whose given label is estimated to be potentially incorrect
#     (e.g. due to annotation error) are flagged as having label issues.
#
#
# Number of examples with this issue: 2136
# Overall dataset quality in terms of this issue: 0.9831
#
# Examples representing most severe instances of this issue:
#        is_label_issue  label_score  given_label  predicted_label
# 10817            True     0.000069            0                1
# 80443            True     0.000072            0                1
# 43360            True     0.000077            0                1
# 65355            True     0.000105            0                1
# 40281            True     0.000113            0                1
#
#
# ------------------ near_duplicate issues -------------------
#
# About this issue:
# 	A (near) duplicate issue refers to two or more examples in
#     a dataset that are extremely similar to each other, relative
#     to the rest of the dataset.  The examples flagged with this issue
#     may be exactly duplicated, or lie atypically close together when
#     represented as vectors (i.e. feature embeddings).
#
#
# Number of examples with this issue: 1906
# Overall dataset quality in terms of this issue: 0.5951
#
# Examples representing most severe instances of this issue:
#        is_near_duplicate_issue  near_duplicate_score near_duplicate_sets  distance_to_nearest_neighbor
# 45556                     True                   0.0             [48059]                           0.0
# 44699                     True                   0.0             [47385]                           0.0
# 44705                     True                   0.0             [18435]                           0.0
# 77565                     True                   0.0             [34651]                           0.0
# 17016                     True                   0.0      [77043, 17831]                           0.0
#
#
# ---------------------- outlier issues ----------------------
#
# About this issue:
# 	Examples that are very different from the rest of the dataset
#     (i.e. potentially out-of-distribution or rare/anomalous instances).
#
#
# Number of examples with this issue: 542
# Overall dataset quality in terms of this issue: 0.3904
#
# Examples representing most severe instances of this issue:
#        is_outlier_issue  outlier_score
# 19623              True       0.057620
# 64840              True       0.058288
# 17787              True       0.060613
# 3132               True       0.061640
# 55458              True       0.063031

# %% [markdown]
# About 1.9% of duplicates, even after our cleaning, are quite expected. Many people don't really care and write short, generic reviews. Still, the data-driven approach confirms it, and we'll take a closer look at this. Additionally, about 2.2% of mislabeled data looks quite problematic.
#
# To programmatically inspect a given issue, `.get_issues()` method is used. For a given issue type (see report above for exact names), it returns a DataFrame with score for each sample. Lower score means higher risk of problems. It also returns a column with a boolean indicator whether a given sample has the problem, e.g. `is_near_duplicate_issue` or `is_label_issue`, which uses a default threshold for the score.
#
# Let's inspect the duplicate issues for now.

# %%
duplicate_issues = lab.get_issues("near_duplicate")
duplicate_issues = duplicate_issues[duplicate_issues["is_near_duplicate_issue"]]
duplicate_issues = duplicate_issues.sort_values(by="near_duplicate_score")

# %% [markdown]
# Row index indicates the row with a problem, and `near_duplicate_sets` are indices of duplicate rows. `distance_to_nearest_neighbor` measures distance between embeddings. Let's see the top 10 cases with most obvious duplicates.

# %%
for idx, row in duplicate_issues.head(10).iterrows():
    text = texts[idx]
    neighbors = texts[row["near_duplicate_sets"][:3]]
    print(f"Text: {text}")
    print(f"\tDuplicates: {neighbors}")
    print()
# Out:
# Text: Reception staff could be friendlier
# 	Duplicates: ['Reception Staff could be friendlier'
#  'The reception staff could be friendlier']
#
# Text: nothing can t fault it
# 	Duplicates: ['Nothing can t fault it']
#
# Text: Good location and Nice staff
# 	Duplicates: ['GOOD LOCATION AND NICE STAFF']
#
# Text: LOCATION WAS REALLY GREAT
# 	Duplicates: ['Location was really great']
#
# Text: The Bed was comfortable
# 	Duplicates: ['The bed was comfortable']
#
# Text: Best hotel in amsterdam
# 	Duplicates: ['Best hotel in Amsterdam' 'The best hotel in amsterdam']
#
# Text: All was wonderful
# 	Duplicates: ['All was wonderful']
#
# Text: view and location
# 	Duplicates: ['View and location']
#
# Text: Fantastic Breakfast
# 	Duplicates: ['Fantastic breakfast']
#
# Text: close to metro
# 	Duplicates: ['Close to metro']

# %% [markdown]
# Yeah, we forgot that `Pandas` is case-sensitive about finding duplicates. So with CleanLab, we identified a problem with our preprocessing. We will filter this in just a bit. Let's also see the last 10 duplicates.

# %%
for idx, row in duplicate_issues.tail(10).iterrows():
    text = texts[idx]
    neighbors = texts[row["near_duplicate_sets"][:3]]
    print(f"Text: {text}")
    print(f"\tDuplicates: {neighbors}")
    print()
# Out:
# Text: The size of the rooms were very small
# 	Duplicates: ['The rooms were very very small']
#
# Text: Excellent location excellent breakfast excellent staff
# 	Duplicates: ['excellent location great staff very good breakfast']
#
# Text: Staff were very pleasant
# 	Duplicates: ['The staff were really pleasant']
#
# Text: The staff were really pleasant
# 	Duplicates: ['Staff were very pleasant']
#
# Text: Very nice and helpfull staff
# 	Duplicates: ['Very nice and very helpful staff']
#
# Text: Very nice and very helpful staff
# 	Duplicates: ['Very nice and helpfull staff']
#
# Text: Breakfast and staff were excellent
# 	Duplicates: ['Staff were great Breakfast was excellent']
#
# Text: Staff were great Breakfast was excellent
# 	Duplicates: ['Breakfast and staff were excellent']
#
# Text: Excellent location friendly and helpful staff
# 	Duplicates: ['Good location friendly and helpful staff'
#  'Good location Friendly and helpful staff']
#
# Text: great location good staff
# 	Duplicates: ['Great location and good staff']

# %% [markdown]
# Definitely similar, but not exactly duplicates. We will remove the case-insensitive duplicates now. Note that we will keep the index to avoid recalculation for inspecting further issues.

# %%
df["text_lower"] = df["text"].str.lower()
df_deduplicated = df.drop_duplicates(subset="text_lower")
df_deduplicated = df_deduplicated.drop(columns="text_lower")
df_deduplicated = df_deduplicated.reset_index(drop=True)
df_deduplicated
# Out:
#                                                     text  label
# 0      Rather slow service at reception bathroom floo...      0
# 1                                      Location AND WIFI      1
# 2                                  Far from tram station      0
# 3               Location to tube station Comfy bed Roomy      1
# 4      Lovely and spotless hotel with an old world ch...      1
# ...                                                  ...    ...
# 99707  Excellent breakfast buffet very handy for tram...      1
# 99708  Easy to get everywhere Very good restaurant ne...      1
# 99709  Excellent location and staff Beautiful authent...      1
# 99710  Our room was just big enough for the bed but w...      0
# 99711  Bit hectic at breakfast Had to ask for tea and...      0
#
# [99712 rows x 2 columns]

# %% [markdown]
# Now we will inspect labels. If our model predicts the label different from the real one with very high confidence, it may be a mislabeled sample.

# %%
label_issues = lab.get_issues("label")
label_issues = label_issues[label_issues["is_label_issue"]]
label_issues = label_issues.sort_values(by="label_score")

top_label_issues_y_true = label_issues.head(10)["given_label"]
top_label_issues_y_pred = label_issues.head(10)["predicted_label"]
top_label_issues_idxs = label_issues.head(10).index
top_label_issues_texts = texts[top_label_issues_idxs]

print("Top 10 label issues")
for text, y_true, y_pred in zip(top_label_issues_texts, top_label_issues_y_true, top_label_issues_y_pred):
    print(f"y_true {y_true}, y_pred {y_pred}, text: {text}")
    print()
# Out:
# Top 10 label issues
# y_true 0, y_pred 1, text: Fantastic very convenient location
#
# y_true 0, y_pred 1, text: Super Great Location
#
# y_true 0, y_pred 1, text: Beautiful hotel an excellent location and fantastic staff
#
# y_true 0, y_pred 1, text: Staff very happy and friendly and vey helpful
#
# y_true 0, y_pred 1, text: Perfect Place Wonderful Staff
#
# y_true 0, y_pred 1, text: Friendly staff great location and clean place
#
# y_true 1, y_pred 0, text: Probably overpriced
#
# y_true 1, y_pred 0, text: There was a problem with the heating system of the room they immediately put an extra heater to the room
#
# y_true 0, y_pred 1, text: great location staff food and service
#
# y_true 0, y_pred 1, text: Great staff and in particular Daphne she supported me through out the stay with tips like places to dine sight seeing and stuff

# %% [markdown]
# The reason for those is most probably that on booking.com there are separate fields for positive and negative reviews. Some people may get confused and put texts in the wrong place. So we also identified a potential UX issue, in addition to the labeling problem.
#
# We will change the labels as suggested by CleanLab.

# %%
# make sure we don't get key errors - we removed some rows earlier during deduplication
label_issues = label_issues[label_issues.index.isin(df_deduplicated.index)]

idxs = label_issues.index.tolist()
pred_labels = label_issues["predicted_label"]

df_fixed = df_deduplicated.copy()
df_fixed.loc[idxs, "label"] = pred_labels
df_fixed
# Out:
#                                                     text  label
# 0      Rather slow service at reception bathroom floo...      0
# 1                                      Location AND WIFI      1
# 2                                  Far from tram station      0
# 3               Location to tube station Comfy bed Roomy      1
# 4      Lovely and spotless hotel with an old world ch...      1
# ...                                                  ...    ...
# 99707  Excellent breakfast buffet very handy for tram...      1
# 99708  Easy to get everywhere Very good restaurant ne...      1
# 99709  Excellent location and staff Beautiful authent...      1
# 99710  Our room was just big enough for the bed but w...      0
# 99711  Bit hectic at breakfast Had to ask for tea and...      0
#
# [99712 rows x 2 columns]

# %% [markdown]
# ### Exercise 3 (1 point)
#
# 1. Print texts from the rows marked as outliers (`outlier` problem) with the strongest confidence (i.e., the lowest score).
# 2. Comment, do you think those samples really are strange? Would you remove them?

# %%
outlier_issues = lab.get_issues("outlier")
outlier_issues = outlier_issues[outlier_issues["is_outlier_issue"]]
outlier_issues = outlier_issues.sort_values(by="outlier_score")

# %%
for idx, row in outlier_issues.head(10).iterrows():
    text = texts[idx]
    score = row["outlier_score"]
    print(f"Outlier score: {score:.4f}, text: {text}")
    print()
# Out:
# Outlier score: 0.0576, text: Lpcation no fpod
#
# Outlier score: 0.0583, text: Change type of below
#
# Outlier score: 0.0606, text: No its already up to the maximun To ask more means exazerate
#
# Outlier score: 0.0616, text: Just not that crazy about Linz
#
# Outlier score: 0.0630, text: Julio is the man
#
# Outlier score: 0.0644, text: Moderne apparatuur in de kamer zoals USB stick contact oplaadpunt in kluis en bluetooth
#
# Outlier score: 0.0665, text: Thatbi oreder champangenon arriva and it wasn t there Had to remind but was sorted quickly
#
# Outlier score: 0.0667, text: Sorry wasn t anticipating this question have just answered it on the last question
#
# Outlier score: 0.0670, text: It s a tad hipstery but that s who they re aiming for I assume
#
# Outlier score: 0.0698, text: Shoild have a better agreement with peaking

# %% [markdown]
# **Comment**: Some are indeed strage like "Julio is the man" or "Change type of below". Most of them covers typos or slang words. Removing them may help, but it's not strictly necessary. We could i.e. give them to human annotators for verification.

# %% [markdown]
# # Model Quality Testing
# This stage is essential for assessing the robustness, reliability, and performance of AI models developed using the curated data. Model Quality Testing enables us to verify that the model meets the intended goals and performs well across various scenarios and data subsets. This not only scrutinizes the accuracy and efficiency of models but also ensures that they are fair, accountable, and transparent in their operations.

# %% [markdown]
# ## Common metrics
#
# Now that our data is cleaned and prepared, we can train a model and proceed to test it. Firstly, we will just look at common numerical metrics, summarizing the model performance over test data. Further, we will perform **behavioral testing**, checking its stability, biases and other problems not visible when just using typical performance metrics on labels.
#
# Firstly, we will focus on just regular metrics, which use predicted probabilities and labels. Our dataset is relatively balanced, which is quite rarely the case. In any case, metrics that take label imbalance into consideration are a good choice. Well-known ones are:
# 1. Precision: if the model predicts the positive class, precision measures how sure we can be that it's really the positive class. High precision means low fraction of false positives (FP).
# 2. Recall: measures how much of the positive class the model detected. High recall means low fraction of false negatives (FN).
# 3. F1-score: a harmonic mean of precision and recall, aggregates them into one number for convenience. Harmonic mean heavily penalizes small numbers, so to get high value, both precision and recall have to be high, not just one of those.
#
# Area Under Receiver Operating Characteristic (AUROC / ROC AUC) is less frequently used in NLP, but has a few beneficial properties. It takes into consideration model probability predictions. For different thresholds (percentage above which we assume positive class) we measure the fractions of true positives and false positives, and aggregate those numbers. To achieve high AUROC, the model has to predict the right class with high probability, and avoid false positives even for low thresholds.
#
# Matthews Correlation Coefficient (MCC) can be thought of as Pearson correlation, but for binary variables. It has favorable statistical properties, and can spot model failures even when accuracy or AUROC are high. In particular, high MCC guarantees high AUROC and typically also other metrics, but not the other way around. For details, see:
# - [Wikipedia summary](https://en.wikipedia.org/wiki/Phi_coefficient#Advantages_over_accuracy_and_F1_score)
# - ["Ten quick tips for machine learning in computational biology" D. Chicco](https://www.ncbi.nlm.nih.gov/pmc/articles/PMC5721660/)
# - ["The advantages of the Matthews correlation coefficient (MCC) over F1 score and accuracy in binary classification evaluation" D. Chicco, G. Jurman](https://www.ncbi.nlm.nih.gov/pmc/articles/PMC6941312/)
# - ["The Matthews correlation coefficient (MCC) should replace the ROC AUC as the standard metric for assessing binary classification" D. Chicco, G. Jurman](https://biodatamining.biomedcentral.com/articles/10.1186/s13040-023-00322-4)
#
# Furthermore, any probabilistic metric like AUROC requires **well-calibrated** models, i.e. predicting probabilities right. Optimizing cross-entropy (log-loss) directly uses class probabilities, therefore logistic regression and neural networks typically are well-calibrated. Tree-based models, Naive Bayes or SVMs are often surprisingly bad at predicting probabilities. If a model is well-calibrated, we can trust that the probability it predicts is close to the true (typically unknown) probability.

# %% [markdown]
# ### Training a classifier
#
# We will fine-tune a simple [DistilBERT](https://huggingface.co/distilbert/distilbert-base-uncased) model (uncased variant) for binary classification. This is a typical HuggingFace code for training. We will evaluate the resulting model on many metrics, to gain more insight into its performance. During training, we will measure MCC every 1000 steps, to check how the training is progressing.

# %%
import torch
from datasets import Dataset, DatasetDict
from sklearn.model_selection import train_test_split


# 60-10-30% split
test_size = int(0.3 * len(df_fixed))
train_size = int(0.6 * len(df_fixed))

df_train, df_test = train_test_split(df_fixed, test_size=test_size, random_state=0, stratify=df_fixed["label"])
df_train, df_valid = train_test_split(df_train, train_size=train_size, random_state=0, stratify=df_train["label"])

datasets_dict = DatasetDict()
datasets_dict["train"] = Dataset.from_pandas(df_train, split="train")
datasets_dict["valid"] = Dataset.from_pandas(df_valid, split="valid")
datasets_dict["test"] = Dataset.from_pandas(df_test, split="test")

# %%
from transformers import AutoTokenizer


tokenizer = AutoTokenizer.from_pretrained("distilbert/distilbert-base-uncased")


def tokenize(examples: dict) -> dict:
    encoded_examples = tokenizer(examples["text"], padding=True, truncation=True)
    encoded_examples["label"] = torch.tensor(examples["label"])
    return encoded_examples


num_cores = joblib.cpu_count(only_physical_cores=True)
datasets_tokenized = datasets_dict.map(tokenize, batched=True)
# Out:
# tokenizer_config.json:   0%|          | 0.00/48.0 [00:00<?, ?B/s]
# config.json:   0%|          | 0.00/483 [00:00<?, ?B/s]
# vocab.txt: 0.00B [00:00, ?B/s]
# tokenizer.json: 0.00B [00:00, ?B/s]
# Map:   0%|          | 0/59827 [00:00<?, ? examples/s]
# Map:   0%|          | 0/9972 [00:00<?, ? examples/s]
# Map:   0%|          | 0/29913 [00:00<?, ? examples/s]

# %%
import os
import random

from sklearn.metrics import matthews_corrcoef
from torch.nn.functional import softmax
from transformers import AutoModelForSequenceClassification, EvalPrediction, Trainer, TrainingArguments


# set determinism settings
os.environ["PYTHONHASHSEED"] = str(0)
random.seed(0)
np.random.seed(0)
torch.manual_seed(0)
torch.cuda.manual_seed_all(0)

model = AutoModelForSequenceClassification.from_pretrained("distilbert/distilbert-base-uncased", num_labels=2)


# freeze some weights to speed up training
for param in model.distilbert.embeddings.parameters():
    param.requires_grad = False

for param in model.distilbert.transformer.parameters():
    param.requires_grad = False


def compute_metrics(eval_pred: EvalPrediction) -> dict:
    y_true = eval_pred.label_ids.ravel()
    logits = torch.from_numpy(eval_pred.predictions)
    y_pred_proba = softmax(logits, dim=1)[:, 1].numpy()
    y_pred = (y_pred_proba >= 0.5).astype(int)
    mcc = matthews_corrcoef(y_true, y_pred)
    return {"MCC": mcc}


training_args = TrainingArguments(
    output_dir="finetuned_model",
    # change num_train_epochs depending on your hardware
    # if lower, increase learning rate and decrease save_steps and eval_steps
    learning_rate=1e-2,
    num_train_epochs=1,
    eval_strategy="steps",
    save_steps=50,
    eval_steps=50,
    save_total_limit=1,
    load_best_model_at_end=True,
    seed=0,
    data_seed=0,
    fp16=True,  # comment this out if you have unsupported hardware
    dataloader_num_workers=1,  # comment out if necessary
)

trainer = Trainer(
    model=model,
    args=training_args,
    train_dataset=datasets_tokenized["train"],
    eval_dataset=datasets_tokenized["valid"],
    tokenizer=tokenizer,
    compute_metrics=compute_metrics,
)
trainer.train()
# Out:
# model.safetensors:   0%|          | 0.00/268M [00:00<?, ?B/s]
# Some weights of DistilBertForSequenceClassification were not initialized from the model checkpoint at distilbert/distilbert-base-uncased and are newly initialized: ['classifier.bias', 'classifier.weight', 'pre_classifier.bias', 'pre_classifier.weight']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.
#     <div>
#
#       <progress value='7479' max='7479' style='width:300px; height:20px; vertical-align: middle;'></progress>
#       [7479/7479 25:25, Epoch 1/1]
#     </div>
#     <table border="1" class="dataframe">
#   <thead>
#  <tr style="text-align: left;">
#       <th>Step</th>
#       <th>Training Loss</th>
#       <th>Validation Loss</th>
#       <th>Mcc</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>50</td>
#       <td>No log</td>
#       <td>0.849516</td>
#       <td>0.677651</td>
#     </tr>
#     <tr>
#       <td>100</td>
#       <td>No log</td>
#       <td>0.648492</td>
#       <td>0.742478</td>
#     </tr>
#     <tr>
#       <td>150</td>
#       <td>No log</td>
#       <td>0.873071</td>
#       <td>0.643454</td>
#     </tr>
#     <tr>
#       <td>200</td>
#       <td>No log</td>
#       <td>0.324566</td>
#       <td>0.818518</td>
#     </tr>
#     <tr>
#       <td>250</td>
#       <td>No log</td>
#       <td>0.281071</td>
#       <td>0.826112</td>
#     </tr>
#     <tr>
#       <td>300</td>
#       <td>No log</td>
#       <td>0.300549</td>
#       <td>0.797648</td>
#     </tr>
#     <tr>
#       <td>350</td>
#       <td>No log</td>
#       <td>0.297945</td>
#       <td>0.824940</td>
#     </tr>
#     <tr>
#       <td>400</td>
#       <td>No log</td>
#       <td>0.384792</td>
#       <td>0.735798</td>
#     </tr>
#     <tr>
#       <td>450</td>
#       <td>No log</td>
#       <td>0.303510</td>
#       <td>0.784314</td>
#     </tr>
#     <tr>
#       <td>500</td>
#       <td>0.556800</td>
#       <td>0.322048</td>
#       <td>0.836286</td>
#     </tr>
#     <tr>
#       <td>550</td>
#       <td>0.556800</td>
#       <td>0.287268</td>
#       <td>0.826803</td>
#     </tr>
#     <tr>
#       <td>600</td>
#       <td>0.556800</td>
#       <td>0.345730</td>
#       <td>0.813510</td>
#     </tr>
#     <tr>
#       <td>650</td>
#       <td>0.556800</td>
#       <td>0.390503</td>
#       <td>0.767091</td>
#     </tr>
#     <tr>
#       <td>700</td>
#       <td>0.556800</td>
#       <td>0.329127</td>
#       <td>0.773769</td>
#     </tr>
#     <tr>
#       <td>750</td>
#       <td>0.556800</td>
#       <td>0.399977</td>
#       <td>0.770600</td>
#     </tr>
#     <tr>
#       <td>800</td>
#       <td>0.556800</td>
#       <td>0.262231</td>
#       <td>0.826669</td>
#     </tr>
#     <tr>
#       <td>850</td>
#       <td>0.556800</td>
#       <td>0.269316</td>
#       <td>0.830851</td>
#     </tr>
#     <tr>
#       <td>900</td>
#       <td>0.556800</td>
#       <td>0.257532</td>
#       <td>0.802125</td>
#     </tr>
#     <tr>
#       <td>950</td>
#       <td>0.556800</td>
#       <td>0.266934</td>
#       <td>0.828411</td>
#     </tr>
#     <tr>
#       <td>1000</td>
#       <td>0.337600</td>
#       <td>0.278546</td>
#       <td>0.808825</td>
#     </tr>
#     <tr>
#       <td>1050</td>
#       <td>0.337600</td>
#       <td>0.490134</td>
#       <td>0.809018</td>
#     </tr>
#     <tr>
#       <td>1100</td>
#       <td>0.337600</td>
#       <td>0.247976</td>
#       <td>0.838147</td>
#     </tr>
#     <tr>
#       <td>1150</td>
#       <td>0.337600</td>
#       <td>0.246320</td>
#       <td>0.809656</td>
#     </tr>
#     <tr>
#       <td>1200</td>
#       <td>0.337600</td>
#       <td>0.273746</td>
#       <td>0.837195</td>
#     </tr>
#     <tr>
#       <td>1250</td>
#       <td>0.337600</td>
#       <td>0.290319</td>
#       <td>0.803196</td>
#     </tr>
#     <tr>
#       <td>1300</td>
#       <td>0.337600</td>
#       <td>0.305085</td>
#       <td>0.794994</td>
#     </tr>
#     <tr>
#       <td>1350</td>
#       <td>0.337600</td>
#       <td>0.271733</td>
#       <td>0.836561</td>
#     </tr>
#     <tr>
#       <td>1400</td>
#       <td>0.337600</td>
#       <td>0.262895</td>
#       <td>0.837220</td>
#     </tr>
#     <tr>
#       <td>1450</td>
#       <td>0.337600</td>
#       <td>0.310037</td>
#       <td>0.840121</td>
#     </tr>
#     <tr>
#       <td>1500</td>
#       <td>0.339300</td>
#       <td>0.260419</td>
#       <td>0.836331</td>
#     </tr>
#     <tr>
#       <td>1550</td>
#       <td>0.339300</td>
#       <td>0.264497</td>
#       <td>0.831754</td>
#     </tr>
#     <tr>
#       <td>1600</td>
#       <td>0.339300</td>
#       <td>0.266099</td>
#       <td>0.837320</td>
#     </tr>
#     <tr>
#       <td>1650</td>
#       <td>0.339300</td>
#       <td>0.346848</td>
#       <td>0.813810</td>
#     </tr>
#     <tr>
#       <td>1700</td>
#       <td>0.339300</td>
#       <td>0.295461</td>
#       <td>0.820412</td>
#     </tr>
#     <tr>
#       <td>1750</td>
#       <td>0.339300</td>
#       <td>0.265851</td>
#       <td>0.844340</td>
#     </tr>
#     <tr>
#       <td>1800</td>
#       <td>0.339300</td>
#       <td>0.311509</td>
#       <td>0.835742</td>
#     </tr>
#     <tr>
#       <td>1850</td>
#       <td>0.339300</td>
#       <td>0.242014</td>
#       <td>0.836172</td>
#     </tr>
#     <tr>
#       <td>1900</td>
#       <td>0.339300</td>
#       <td>0.234429</td>
#       <td>0.846436</td>
#     </tr>
#     <tr>
#       <td>1950</td>
#       <td>0.339300</td>
#       <td>0.255674</td>
#       <td>0.844713</td>
#     </tr>
#     <tr>
#       <td>2000</td>
#       <td>0.303500</td>
#       <td>0.270267</td>
#       <td>0.846747</td>
#     </tr>
#     <tr>
#       <td>2050</td>
#       <td>0.303500</td>
#       <td>0.265349</td>
#       <td>0.831830</td>
#     </tr>
#     <tr>
#       <td>2100</td>
#       <td>0.303500</td>
#       <td>0.256108</td>
#       <td>0.847307</td>
#     </tr>
#     <tr>
#       <td>2150</td>
#       <td>0.303500</td>
#       <td>0.271692</td>
#       <td>0.841880</td>
#     </tr>
#     <tr>
#       <td>2200</td>
#       <td>0.303500</td>
#       <td>0.273632</td>
#       <td>0.824159</td>
#     </tr>
#     <tr>
#       <td>2250</td>
#       <td>0.303500</td>
#       <td>0.260054</td>
#       <td>0.834498</td>
#     </tr>
#     <tr>
#       <td>2300</td>
#       <td>0.303500</td>
#       <td>0.277608</td>
#       <td>0.841833</td>
#     </tr>
#     <tr>
#       <td>2350</td>
#       <td>0.303500</td>
#       <td>0.250589</td>
#       <td>0.843067</td>
#     </tr>
#     <tr>
#       <td>2400</td>
#       <td>0.303500</td>
#       <td>0.231214</td>
#       <td>0.844263</td>
#     </tr>
#     <tr>
#       <td>2450</td>
#       <td>0.303500</td>
#       <td>0.227715</td>
#       <td>0.849108</td>
#     </tr>
#     <tr>
#       <td>2500</td>
#       <td>0.280400</td>
#       <td>0.286633</td>
#       <td>0.850943</td>
#     </tr>
#     <tr>
#       <td>2550</td>
#       <td>0.280400</td>
#       <td>0.259555</td>
#       <td>0.844444</td>
#     </tr>
#     <tr>
#       <td>2600</td>
#       <td>0.280400</td>
#       <td>0.243830</td>
#       <td>0.845956</td>
#     </tr>
#     <tr>
#       <td>2650</td>
#       <td>0.280400</td>
#       <td>0.249176</td>
#       <td>0.850564</td>
#     </tr>
#     <tr>
#       <td>2700</td>
#       <td>0.280400</td>
#       <td>0.259304</td>
#       <td>0.838252</td>
#     </tr>
#     <tr>
#       <td>2750</td>
#       <td>0.280400</td>
#       <td>0.254194</td>
#       <td>0.847481</td>
#     </tr>
#     <tr>
#       <td>2800</td>
#       <td>0.280400</td>
#       <td>0.244001</td>
#       <td>0.840781</td>
#     </tr>
#     <tr>
#       <td>2850</td>
#       <td>0.280400</td>
#       <td>0.238250</td>
#       <td>0.847495</td>
#     </tr>
#     <tr>
#       <td>2900</td>
#       <td>0.280400</td>
#       <td>0.250724</td>
#       <td>0.843658</td>
#     </tr>
#     <tr>
#       <td>2950</td>
#       <td>0.280400</td>
#       <td>0.241755</td>
#       <td>0.848510</td>
#     </tr>
#     <tr>
#       <td>3000</td>
#       <td>0.265700</td>
#       <td>0.278110</td>
#       <td>0.851014</td>
#     </tr>
#     <tr>
#       <td>3050</td>
#       <td>0.265700</td>
#       <td>0.270243</td>
#       <td>0.851296</td>
#     </tr>
#     <tr>
#       <td>3100</td>
#       <td>0.265700</td>
#       <td>0.236016</td>
#       <td>0.853769</td>
#     </tr>
#     <tr>
#       <td>3150</td>
#       <td>0.265700</td>
#       <td>0.233625</td>
#       <td>0.837927</td>
#     </tr>
#     <tr>
#       <td>3200</td>
#       <td>0.265700</td>
#       <td>0.276203</td>
#       <td>0.847926</td>
#     </tr>
#     <tr>
#       <td>3250</td>
#       <td>0.265700</td>
#       <td>0.264952</td>
#       <td>0.840628</td>
#     </tr>
#     <tr>
#       <td>3300</td>
#       <td>0.265700</td>
#       <td>0.245245</td>
#       <td>0.845128</td>
#     </tr>
#     <tr>
#       <td>3350</td>
#       <td>0.265700</td>
#       <td>0.239795</td>
#       <td>0.838507</td>
#     </tr>
#     <tr>
#       <td>3400</td>
#       <td>0.265700</td>
#       <td>0.324013</td>
#       <td>0.842970</td>
#     </tr>
#     <tr>
#       <td>3450</td>
#       <td>0.265700</td>
#       <td>0.235568</td>
#       <td>0.847717</td>
# TrainOutput(global_step=7479, training_loss=0.2992380741270871, metrics={'train_runtime': 1524.2715, 'train_samples_per_second': 39.25, 'train_steps_per_second': 4.907, 'total_flos': 6051901435391808.0, 'train_loss': 0.2992380741270871, 'epoch': 1.0})

# %%
from sklearn.metrics import f1_score, matthews_corrcoef, precision_score, recall_score, roc_auc_score


pred_output = trainer.predict(datasets_tokenized["test"])
logits = torch.from_numpy(pred_output.predictions)
y_pred_proba = softmax(logits, dim=1)[:, 1].numpy()
y_pred = (y_pred_proba >= 0.5).astype(int)
y_test = datasets_tokenized["test"]["label"]

print(f"Precision: {precision_score(y_test, y_pred):.2%}")
print(f"Recall: {recall_score(y_test, y_pred):.2%}")
print(f"F1-score: {f1_score(y_test, y_pred):.2%}")
print(f"AUROC: {roc_auc_score(y_test, y_pred_proba):.2%}")
print(f"MCC: {matthews_corrcoef(y_test, y_pred):.2%}")
# Out:
# Precision: 94.30%
# Recall: 92.49%
# F1-score: 93.39%
# AUROC: 96.91%
# MCC: 85.48%

# %% [markdown]
# Generally, we seem to have a quite good classifier, but a significantly lower MCC may indicate some problems. Although, we have to remember that these are just aggregate numbers, and may lead to wrong conclusions. Let's inspect some predictions manually.
#
# The simplest way to check is to do something similar to CleanLab label check. We take the predicted probabilities and check the test instances where:
# - the model predicted the lowest probability for the positive class, or the highest probability for the negative class
# - where the model was the most uncertain, i.e., the probability was closest to 50%

# %% [markdown]
# ### Exercise 4 (1 point)
#
# From test data, select:
# - Ten worst false positives (with the highest predicted probability, where the true class is negative)
# - Ten worst false negatives (with the lowest predicted probability among the truly positive class)
# - Ten most uncertain predictions (with probability closest to 50%)
#
# Do you see any obvious problems here?

# %%
df_pred = datasets_tokenized["test"].to_pandas()[['text', 'label']].reset_index(drop=True)
df_pred["y_pred"] = y_pred
df_pred["y_pred_proba"] = y_pred_proba

# %%
false_positives = df_pred[(df_pred["label"] == 0) & (df_pred["y_pred"] == 1)]
false_positives.sort_values(by="y_pred_proba", ascending=False).head(10)
# Out:
#                                                     text  label  y_pred  \
# 7458   Lovely hotel spacious rooms comfortable beds n...      0       1
# 1822   The room was great and staff very helpful Love...      0       1
# 11065      Friendly staff great location and clean place      0       1
# 28750  Friendly staff clean and excellently located W...      0       1
# 4312   Location was wonderful Staff were very nice Ro...      0       1
# 14041  great location friendly staff great facilities...      0       1
# 28260  The location was excellent The rooms and commo...      0       1
# 2783   Great and friendly staff happy to give you ins...      0       1
# 16835  Staff were fantastic very friendly and helpful...      0       1
# 27197  Great location and convenient to transportatio...      0       1
#
#        y_pred_proba
# 7458       0.999997
# 1822       0.999995
# 11065      0.999994
# 28750      0.999986
# 4312       0.999985
# 14041      0.999982
# 28260      0.999976
# 2783       0.999975
# 16835      0.999969
# 27197      0.999957

# %%
false_negatives = df_pred[(df_pred["label"] == 1) & (df_pred["y_pred"] == 0)]
false_negatives.sort_values(by="y_pred_proba", ascending=True).head(10)
# Out:
#                                                     text  label  y_pred  \
# 26239  No in room refrigerators in most rooms and low...      1       0
# 23939  Service is bad except for on guy in the night ...      1       0
# 25693  I have asked a double bed but the room had 2 t...      1       0
# 21522  Electronics were faulty and heating took a whi...      1       0
# 26706  Bed comfortable Bedroom walls paper thin Sound...      1       0
# 14734  Cleaning staff made far too much noise and kep...      1       0
# 9745   Nothing like the level of cleanliness renovati...      1       0
# 13570  The bathroom there was a hole above the shower...      1       0
# 1690   the room was quite noisy on an evening therefo...      1       0
# 2894   Gimmicks in the rooms for electrics are cool b...      1       0
#
#        y_pred_proba
# 26239      0.000115
# 23939      0.000122
# 25693      0.000196
# 21522      0.000220
# 26706      0.000400
# 14734      0.000451
# 9745       0.000466
# 13570      0.000469
# 1690       0.000508
# 2894       0.000561

# %%
most_uncertain = df_pred.copy()
most_uncertain["uncertainty"] = np.abs(most_uncertain["y_pred_proba"] - 0.5)
most_uncertain = most_uncertain.sort_values(by="uncertainty", ascending=True)
most_uncertain.head(10)
# Out:
#                                                     text  label  y_pred  \
# 3375   we did not eat at the hotel but our stay was g...      1       0
# 2988           Breakfast was good busy but food was nice      1       0
# 12014      Location Breakfast in general early breakfast      1       1
# 26240                           Would love extra pillows      0       0
# 23207  Good solution for unavailability of reserved room      1       1
# 1075                          In general it was all good      1       0
# 16461                             better value for money      0       1
# 24274  Location SERVICE rooms What more can i ask Hom...      1       0
# 11722                               for us a longer stay      0       0
# 15682                                   View from window      1       1
#
#        y_pred_proba  uncertainty
# 3375       0.499849     0.000151
# 2988       0.499359     0.000641
# 12014      0.500687     0.000687
# 26240      0.499313     0.000687
# 23207      0.500818     0.000818
# 1075       0.498437     0.001563
# 16461      0.501572     0.001572
# 24274      0.498215     0.001785
# 11722      0.498091     0.001909
# 15682      0.502014     0.002014

# %% [markdown]
# **Problems**: Labels are missclassified! Positive reviews were assigned label "0" and negative reviews label "1".
#
# Reviews with nearly 50% probability are hard to classify even for humans, i.e.e: "Good solution for unavailability of reserved room" - so it's understandable that the model struggles here.

# %% [markdown]
# ## Behavioral testing with Giskard
#
# [Giskard](https://github.com/Giskard-AI/giskard) is a library for testing tabular, NLP, vision models, and LLMs. It can detect issues like over- and underconfidence, unfairness (sensitivity to gender, religion, etc.), bias towards certain words or segments, etc. There are easily usable integrations with scikit-learn, HuggingFace or LangChain.
#
# It mostly relies on **slicing** and **input perturbation** techniques. Slicing analyzes model performance in slices (segments) e.g. when specific words appear. Input perturbations (also called transformations) slightly modify the input data and compare the model behavior between original and perturbed data. These can be introducing typos, lower- or uppercase, changing gender and religion words etc.
#
# Giskard requires passing a prediction function, which takes raw test data and returns model predictions, as well as a few other configuration elements. Importantly, if we want interpretable perturbations, we need to pass raw texts as inputs, so that they can be modified. Therefore, the embedding calculation needs to be inside this prediction function. We also use the logistic classifier trained above.
#
# **Warning:** this can take a bit. If it takes too long, you can subsample the test set to make it smaller.

# %%
from giskard import Model as GiskardModel, Dataset as GiskardDataset, scan, testing
from transformers import pipeline

trained_model = trainer.model
trained_model.eval()
model_pipeline = pipeline(
    "text-classification", 
    model=trained_model, 
    tokenizer=tokenizer,
    device="cuda" if torch.cuda.is_available() else "cpu",
)


@torch.no_grad()
def prediction_function(df: pd.DataFrame) -> np.ndarray:
    pred_output = model_pipeline(df["text"].tolist())
    y_pred_proba = [pred["score"] for pred in pred_output]
    return y_pred_proba


giskard_dataset = GiskardDataset(df_test, target="label")

giskard_model = GiskardModel(
    model=prediction_function,
    model_type="classification",
    classification_labels=[0, 1],
    feature_names=["text"],
)
scan_results = scan(giskard_model, giskard_dataset, verbose=False)
display(scan_results)
# Out:
# Device set to use cuda
# 2025-11-24 21:35:44,555 pid:5365 MainThread giskard.datasets.base INFO     Your 'pandas.DataFrame' is successfully wrapped by Giskard's 'Dataset' wrapper class.
# 2025-11-24 21:35:44,556 pid:5365 MainThread giskard.models.automodel INFO     Your 'prediction_function' is successfully wrapped by Giskard's 'PredictionFunctionModel' wrapper class.
# 2025-11-24 21:35:44,561 pid:5365 MainThread giskard.datasets.base INFO     Casting dataframe columns from {'text': 'object'} to {'text': 'object'}
# 2025-11-24 21:35:44,597 pid:5365 MainThread giskard.models.base.wrapper WARNING  Please make sure that your model's output corresponds to the second label in classification_labels.
# 2025-11-24 21:35:44,597 pid:5365 MainThread giskard.utils.logging_utils INFO     Predicted dataset with shape (10, 2) executed in 0:00:00.039079
# 2025-11-24 21:35:44,602 pid:5365 MainThread giskard.datasets.base INFO     Casting dataframe columns from {'text': 'object'} to {'text': 'object'}
# 2025-11-24 21:35:44,608 pid:5365 MainThread giskard.utils.logging_utils INFO     Predicted dataset with shape (1, 2) executed in 0:00:00.009577
# 2025-11-24 21:35:44,611 pid:5365 MainThread giskard.datasets.base INFO     Casting dataframe columns from {'text': 'object'} to {'text': 'object'}
# 2025-11-24 21:35:44,612 pid:5365 MainThread giskard.utils.logging_utils INFO     Predicted dataset with shape (10, 2) executed in 0:00:00.003292
# 2025-11-24 21:35:44,674 pid:5365 MainThread giskard.datasets.base INFO     Casting dataframe columns from {'text': 'object'} to {'text': 'object'}
# 2025-11-24 21:36:31,978 pid:5365 MainThread giskard.utils.logging_utils INFO     Predicted dataset with shape (29913, 2) executed in 0:00:47.366266
# Your model is successfully validated.
# 2025-11-24 21:36:31,981 pid:5365 MainThread giskard.scanner.logger INFO     Running detectors: ['DataLeakageDetector', 'EthicalBiasDetector', 'TextPerturbationDetector', 'NumericalPerturbationDetector', 'SpuriousCorrelationDetector', 'OverconfidenceDetector', 'UnderconfidenceDetector', 'StochasticityDetector', 'PerformanceBiasDetector']
# 2025-11-24 21:36:31,981 pid:5365 MainThread giskard.scanner.logger INFO     DataLeakageDetector: Running
# 2025-11-24 21:36:32,012 pid:5365 MainThread giskard.datasets.base INFO     Casting dataframe columns from {'text': 'object'} to {'text': 'object'}
# 2025-11-24 21:36:32,017 pid:5365 MainThread giskard.utils.logging_utils INFO     Predicted dataset with shape (29913, 2) executed in 0:00:00.035769
# 2025-11-24 21:36:32,021 pid:5365 MainThread giskard.datasets.base INFO     Casting dataframe columns from {'text': 'object'} to {'text': 'object'}
# 2025-11-24 21:36:32,024 pid:5365 MainThread giskard.utils.logging_utils INFO     Predicted dataset with shape (1, 2) executed in 0:00:00.003559
# 2025-11-24 21:36:32,026 pid:5365 MainThread giskard.datasets.base INFO     Casting dataframe columns from {'text': 'object'} to {'text': 'object'}
# 2025-11-24 21:36:32,031 pid:5365 MainThread giskard.utils.logging_utils INFO     Predicted dataset with shape (1, 2) executed in 0:00:00.005305
# 2025-11-24 21:36:32,033 pid:5365 MainThread giskard.datasets.base INFO     Casting dataframe columns from {'text': 'object'} to {'text': 'object'}
# 2025-11-24 21:36:32,039 pid:5365 MainThread giskard.utils.logging_utils INFO     Predicted dataset with shape (1, 2) executed in 0:00:00.007011
# 2025-11-24 21:36:32,041 pid:5365 MainThread giskard.datasets.base INFO     Casting dataframe columns from {'text': 'object'} to {'text': 'object'}
# 2025-11-24 21:36:32,047 pid:5365 MainThread giskard.utils.logging_utils INFO     Predicted dataset with shape (1, 2) executed in 0:00:00.006638
# 2025-11-24 21:36:32,049 pid:5365 MainThread giskard.datasets.base INFO     Casting dataframe columns from {'text': 'object'} to {'text': 'object'}
# 2025-11-24 21:36:32,055 pid:5365 MainThread giskard.utils.logging_utils INFO     Predicted dataset with shape (1, 2) executed in 0:00:00.006964
# 2025-11-24 21:36:32,057 pid:5365 MainThread giskard.datasets.base INFO     Casting dataframe columns from {'text': 'object'} to {'text': 'object'}
# 2025-11-24 21:36:32,060 pid:5365 MainThread giskard.utils.logging_utils INFO     Predicted dataset with shape (1, 2) executed in 0:00:00.003366
# 2025-11-24 21:36:32,062 pid:5365 MainThread giskard.datasets.base INFO     Casting dataframe columns from {'text': 'object'} to {'text': 'object'}
# 2025-11-24 21:36:32,068 pid:5365 MainThread giskard.utils.logging_utils INFO     Predicted dataset with shape (1, 2) executed in 0:00:00.006911
# 2025-11-24 21:36:32,071 pid:5365 MainThread giskard.datasets.base INFO     Casting dataframe columns from {'text': 'object'} to {'text': 'object'}
# You seem to be using the pipelines sequentially on GPU. In order to maximize efficiency please use a dataset
# 2025-11-24 21:36:32,076 pid:5365 MainThread giskard.utils.logging_utils INFO     Predicted dataset with shape (1, 2) executed in 0:00:00.005671
# 2025-11-24 21:36:32,077 pid:5365 MainThread giskard.datasets.base INFO     Casting dataframe columns from {'text': 'object'} to {'text': 'object'}
# 2025-11-24 21:36:32,080 pid:5365 MainThread giskard.utils.logging_utils INFO     Predicted dataset with shape (1, 2) executed in 0:00:00.003421
# 2025-11-24 21:36:32,082 pid:5365 MainThread giskard.datasets.base INFO     Casting dataframe columns from {'text': 'object'} to {'text': 'object'}
# 2025-11-24 21:36:32,085 pid:5365 MainThread giskard.utils.logging_utils INFO     Predicted dataset with shape (1, 2) executed in 0:00:00.003754
# 2025-11-24 21:36:32,087 pid:5365 MainThread giskard.datasets.base INFO     Casting dataframe columns from {'text': 'object'} to {'text': 'object'}
# 2025-11-24 21:36:32,092 pid:5365 MainThread giskard.utils.logging_utils INFO     Predicted dataset with shape (1, 2) executed in 0:00:00.005069
# 2025-11-24 21:36:32,093 pid:5365 MainThread giskard.datasets.base INFO     Casting dataframe columns from {'text': 'object'} to {'text': 'object'}
# 2025-11-24 21:36:32,097 pid:5365 MainThread giskard.utils.logging_utils INFO     Predicted dataset with shape (1, 2) executed in 0:00:00.003608
# 2025-11-24 21:36:32,099 pid:5365 MainThread giskard.datasets.base INFO     Casting dataframe columns from {'text': 'object'} to {'text': 'object'}
# 2025-11-24 21:36:32,102 pid:5365 MainThread giskard.utils.logging_utils INFO     Predicted dataset with shape (1, 2) executed in 0:00:00.003662
# 2025-11-24 21:36:32,104 pid:5365 MainThread giskard.datasets.base INFO     Casting dataframe columns from {'text': 'object'} to {'text': 'object'}
# 2025-11-24 21:36:32,108 pid:5365 MainThread giskard.utils.logging_utils INFO     Predicted dataset with shape (1, 2) executed in 0:00:00.004155
# 2025-11-24 21:36:32,110 pid:5365 MainThread giskard.datasets.base INFO     Casting dataframe columns from {'text': 'object'} to {'text': 'object'}
# 2025-11-24 21:36:32,116 pid:5365 MainThread giskard.utils.logging_utils INFO     Predicted dataset with shape (1, 2) executed in 0:00:00.006583
# 2025-11-24 21:36:32,118 pid:5365 MainThread giskard.datasets.base INFO     Casting dataframe columns from {'text': 'object'} to {'text': 'object'}
# 2025-11-24 21:36:32,121 pid:5365 MainThread giskard.utils.logging_utils INFO     Predicted dataset with shape (1, 2) executed in 0:00:00.003408
# 2025-11-24 21:36:32,123 pid:5365 MainThread giskard.datasets.base INFO     Casting dataframe columns from {'text': 'object'} to {'text': 'object'}
# 2025-11-24 21:36:32,127 pid:5365 MainThread giskard.utils.logging_utils INFO     Predicted dataset with shape (1, 2) executed in 0:00:00.004380
# 2025-11-24 21:36:32,128 pid:5365 MainThread giskard.datasets.base INFO     Casting dataframe columns from {'text': 'object'} to {'text': 'object'}
# 2025-11-24 21:36:32,132 pid:5365 MainThread giskard.utils.logging_utils INFO     Predicted dataset with shape (1, 2) executed in 0:00:00.004691
# 2025-11-24 21:36:32,134 pid:5365 MainThread giskard.datasets.base INFO     Casting dataframe columns from {'text': 'object'} to {'text': 'object'}
# 2025-11-24 21:36:32,137 pid:5365 MainThread giskard.utils.logging_utils INFO     Predicted dataset with shape (1, 2) executed in 0:00:00.003325
# 2025-11-24 21:36:32,138 pid:5365 MainThread giskard.datasets.base INFO     Casting dataframe columns from {'text': 'object'} to {'text': 'object'}
# 2025-11-24 21:36:32,142 pid:5365 MainThread giskard.utils.logging_utils INFO     Predicted dataset with shape (1, 2) executed in 0:00:00.003500
# 2025-11-24 21:36:32,143 pid:5365 MainThread giskard.datasets.base INFO     Casting dataframe columns from {'text': 'object'} to {'text': 'object'}
# 2025-11-24 21:36:32,146 pid:5365 MainThread giskard.utils.logging_utils INFO     Predicted dataset with shape (1, 2) executed in 0:00:00.003253
# 2025-11-24 21:36:32,148 pid:5365 MainThread giskard.datasets.base INFO     Casting dataframe columns from {'text': 'object'} to {'text': 'object'}
# 2025-11-24 21:36:32,151 pid:5365 MainThread giskard.utils.logging_utils INFO     Predicted dataset with shape (1, 2) executed in 0:00:00.004076
# 2025-11-24 21:36:32,154 pid:5365 MainThread giskard.datasets.base INFO     Casting dataframe columns from {'text': 'object'} to {'text': 'object'}
# 2025-11-24 21:36:32,158 pid:5365 MainThread giskard.utils.logging_utils INFO     Predicted dataset with shape (1, 2) executed in 0:00:00.004445
# 2025-11-24 21:36:32,159 pid:5365 MainThread giskard.datasets.base INFO     Casting dataframe columns from {'text': 'object'} to {'text': 'object'}
# 2025-11-24 21:36:32,162 pid:5365 MainThread giskard.utils.logging_utils INFO     Predicted dataset with shape (1, 2) executed in 0:00:00.003212
# 2025-11-24 21:36:32,164 pid:5365 MainThread giskard.datasets.base INFO     Casting dataframe columns from {'text': 'object'} to {'text': 'object'}
# 2025-11-24 21:36:32,169 pid:5365 MainThread giskard.utils.logging_utils INFO     Predicted dataset with shape (1, 2) executed in 0:00:00.005967
# 2025-11-24 21:36:32,171 pid:5365 MainThread giskard.datasets.base INFO     Casting dataframe columns from {'text': 'object'} to {'text': 'object'}
# 2025-11-24 21:36:32,174 pid:5365 MainThread giskard.utils.logging_utils INFO     Predicted dataset with shape (1, 2) executed in 0:00:00.003574
# 2025-11-24 21:36:32,175 pid:5365 MainThread giskard.datasets.base INFO     Casting dataframe columns from {'text': 'object'} to {'text': 'object'}
# 2025-11-24 21:36:32,181 pid:5365 MainThread giskard.utils.logging_utils INFO     Predicted dataset with shape (1, 2) executed in 0:00:00.005797
# 2025-11-24 21:36:32,182 pid:5365 MainThread giskard.datasets.base INFO     Casting dataframe columns from {'text': 'object'} to {'text': 'object'}
# 2025-11-24 21:36:32,185 pid:5365 MainThread giskard.utils.logging_utils INFO     Predicted dataset with shape (1, 2) executed in 0:00:00.003360
# 2025-11-24 21:36:32,187 pid:5365 MainThread giskard.datasets.base INFO     Casting dataframe columns from {'text': 'object'} to {'text': 'object'}
# 2025-11-24 21:36:32,193 pid:5365 MainThread giskard.utils.logging_utils INFO     Predicted dataset with shape (1, 2) executed in 0:00:00.006474
# 2025-11-24 21:36:32,196 pid:5365 MainThread giskard.datasets.base INFO     Casting dataframe columns from {'text': 'object'} to {'text': 'object'}
# 2025-11-24 21:36:32,203 pid:5365 MainThread giskard.utils.logging_utils INFO     Predicted dataset with shape (1, 2) executed in 0:00:00.008259
# 2025-11-24 21:36:32,205 pid:5365 MainThread giskard.datasets.base INFO     Casting dataframe columns from {'text': 'object'} to {'text': 'object'}
# 2025-11-24 21:36:32,209 pid:5365 MainThread giskard.utils.logging_utils INFO     Predicted dataset with shape (1, 2) executed in 0:00:00.003813
# 2025-11-24 21:36:32,210 pid:5365 MainThread giskard.datasets.base INFO     Casting dataframe columns from {'text': 'object'} to {'text': 'object'}
# 2025-11-24 21:36:32,216 pid:5365 MainThread giskard.utils.logging_utils INFO     Predicted dataset with shape (1, 2) executed in 0:00:00.006525
# 2025-11-24 21:36:32,218 pid:5365 MainThread giskard.datasets.base INFO     Casting dataframe columns from {'text': 'object'} to {'text': 'object'}
# 2025-11-24 21:36:32,224 pid:5365 MainThread giskard.utils.logging_utils INFO     Predicted dataset with shape (1, 2) executed in 0:00:00.006751
# 2025-11-24 21:36:32,226 pid:5365 MainThread giskard.datasets.base INFO     Casting dataframe columns from {'text': 'object'} to {'text': 'object'}
# 2025-11-24 21:36:32,230 pid:5365 MainThread giskard.utils.logging_utils INFO     Predicted dataset with shape (1, 2) executed in 0:00:00.004451
# 2025-11-24 21:36:32,232 pid:5365 MainThread giskard.datasets.base INFO     Casting dataframe columns from {'text': 'object'} to {'text': 'object'}
# 2025-11-24 21:36:32,236 pid:5365 MainThread giskard.utils.logging_utils INFO     Predicted dataset with shape (1, 2) executed in 0:00:00.004824
# 2025-11-24 21:36:32,238 pid:5365 MainThread giskard.datasets.base INFO     Casting dataframe columns from {'text': 'object'} to {'text': 'object'}
# 2025-11-24 21:36:32,244 pid:5365 MainThread giskard.utils.logging_utils INFO     Predicted dataset with shape (1, 2) executed in 0:00:00.006531
# 2025-11-24 21:36:32,245 pid:5365 MainThread giskard.datasets.base INFO     Casting dataframe columns from {'text': 'object'} to {'text': 'object'}
# 2025-11-24 21:36:32,251 pid:5365 MainThread giskard.utils.logging_utils INFO     Predicted dataset with shape (1, 2) executed in 0:00:00.006122
# 2025-11-24 21:36:32,253 pid:5365 MainThread giskard.datasets.base INFO     Casting dataframe columns from {'text': 'object'} to {'text': 'object'}
# 2025-11-24 21:36:32,259 pid:5365 MainThread giskard.utils.logging_utils INFO     Predicted dataset with shape (1, 2) executed in 0:00:00.006486
# 2025-11-24 21:36:32,260 pid:5365 MainThread giskard.datasets.base INFO     Casting dataframe columns from {'text': 'object'} to {'text': 'object'}
# 2025-11-24 21:36:32,266 pid:5365 MainThread giskard.utils.logging_utils INFO     Predicted dataset with shape (1, 2) executed in 0:00:00.006265
# 2025-11-24 21:36:32,268 pid:5365 MainThread giskard.datasets.base INFO     Casting dataframe columns from {'text': 'object'} to {'text': 'object'}
# 2025-11-24 21:36:32,274 pid:5365 MainThread giskard.utils.logging_utils INFO     Predicted dataset with shape (1, 2) executed in 0:00:00.006460
# 2025-11-24 21:36:32,275 pid:5365 MainThread giskard.datasets.base INFO     Casting dataframe columns from {'text': 'object'} to {'text': 'object'}
# 2025-11-24 21:36:32,282 pid:5365 MainThread giskard.utils.logging_utils INFO     Predicted dataset with shape (1, 2) executed in 0:00:00.006643
# 2025-11-24 21:36:32,283 pid:5365 MainThread giskard.datasets.base INFO     Casting dataframe columns from {'text': 'object'} to {'text': 'object'}
# 2025-11-24 21:36:32,288 pid:5365 MainThread giskard.utils.logging_utils INFO     Predicted dataset with shape (1, 2) executed in 0:00:00.005067
# 2025-11-24 21:36:32,290 pid:5365 MainThread giskard.datasets.base INFO     Casting dataframe columns from {'text': 'object'} to {'text': 'object'}
# 2025-11-24 21:36:32,297 pid:5365 MainThread giskard.utils.logging_utils INFO     Predicted dataset with shape (1, 2) executed in 0:00:00.007742
# 2025-11-24 21:36:32,299 pid:5365 MainThread giskard.datasets.base INFO     Casting dataframe columns from {'text': 'object'} to {'text': 'object'}
# 2025-11-24 21:36:32,303 pid:5365 MainThread giskard.utils.logging_utils INFO     Predicted dataset with shape (1, 2) executed in 0:00:00.004708
# 2025-11-24 21:36:32,305 pid:5365 MainThread giskard.datasets.base INFO     Casting dataframe columns from {'text': 'object'} to {'text': 'object'}
# 2025-11-24 21:36:32,311 pid:5365 MainThread giskard.utils.logging_utils INFO     Predicted dataset with shape (1, 2) executed in 0:00:00.007079
# 2025-11-24 21:36:32,313 pid:5365 MainThread giskard.datasets.base INFO     Casting dataframe columns from {'text': 'object'} to {'text': 'object'}
# 2025-11-24 21:36:32,318 pid:5365 MainThread giskard.utils.logging_utils INFO     Predicted dataset with shape (1, 2) executed in 0:00:00.005556
# 2025-11-24 21:36:32,320 pid:5365 MainThread giskard.datasets.base INFO     Casting dataframe columns from {'text': 'object'} to {'text': 'object'}
# 2025-11-24 21:36:32,324 pid:5365 MainThread giskard.utils.logging_utils INFO     Predicted dataset with shape (1, 2) executed in 0:00:00.004403
# 2025-11-24 21:36:32,327 pid:5365 MainThread giskard.datasets.base INFO     Casting dataframe columns from {'text': 'object'} to {'text': 'object'}
# 2025-11-24 21:36:32,332 pid:5365 MainThread giskard.utils.logging_utils INFO     Predicted dataset with shape (1, 2) executed in 0:00:00.005795
# 2025-11-24 21:36:32,335 pid:5365 MainThread giskard.datasets.base INFO     Casting dataframe columns from {'text': 'object'} to {'text': 'object'}
# 2025-11-24 21:36:32,342 pid:5365 MainThread giskard.utils.logging_utils INFO     Predicted dataset with shape (1, 2) executed in 0:00:00.007734
# 2025-11-24 21:36:32,345 pid:5365 MainThread giskard.datasets.base INFO     Casting dataframe columns from {'text': 'object'} to {'text': 'object'}
# 2025-11-24 21:36:32,350 pid:5365 MainThread giskard.utils.logging_utils INFO     Predicted dataset with shape (1, 2) executed in 0:00:00.005463
# 2025-11-24 21:36:32,351 pid:5365 MainThread giskard.datasets.base INFO     Casting dataframe columns from {'text': 'object'} to {'text': 'object'}
# 2025-11-24 21:36:32,355 pid:5365 MainThread giskard.utils.logging_utils INFO     Predicted dataset with shape (1, 2) executed in 0:00:00.004335
# 2025-11-24 21:36:32,357 pid:5365 MainThread giskard.datasets.base INFO     Casting dataframe columns from {'text': 'object'} to {'text': 'object'}
# 2025-11-24 21:36:32,364 pid:5365 MainThread giskard.utils.logging_utils INFO     Predicted dataset with shape (1, 2) executed in 0:00:00.007728
# 2025-11-24 21:36:32,366 pid:5365 MainThread giskard.datasets.base INFO     Casting dataframe columns from {'text': 'object'} to {'text': 'object'}
# 2025-11-24 21:36:32,371 pid:5365 MainThread giskard.utils.logging_utils INFO     Predicted dataset with shape (1, 2) executed in 0:00:00.005312
# 2025-11-24 21:36:32,373 pid:5365 MainThread giskard.datasets.base INFO     Casting dataframe columns from {'text': 'object'} to {'text': 'object'}
# 2025-11-24 21:36:32,380 pid:5365 MainThread giskard.utils.logging_utils INFO     Predicted dataset with shape (1, 2) executed in 0:00:00.007131
# 2025-11-24 21:36:32,382 pid:5365 MainThread giskard.datasets.base INFO     Casting dataframe columns from {'text': 'object'} to {'text': 'object'}
# 2025-11-24 21:36:32,386 pid:5365 MainThread giskard.utils.logging_utils INFO     Predicted dataset with shape (1, 2) executed in 0:00:00.004728
# 2025-11-24 21:36:32,388 pid:5365 MainThread giskard.datasets.base INFO     Casting dataframe columns from {'text': 'object'} to {'text': 'object'}
# 2025-11-24 21:36:32,397 pid:5365 MainThread giskard.utils.logging_utils INFO     Predicted dataset with shape (1, 2) executed in 0:00:00.009821
# 2025-11-24 21:36:32,400 pid:5365 MainThread giskard.datasets.base INFO     Casting dataframe columns from {'text': 'object'} to {'text': 'object'}
# 2025-11-24 21:36:32,406 pid:5365 MainThread giskard.utils.logging_utils INFO     Predicted dataset with shape (1, 2) executed in 0:00:00.007087
# 2025-11-24 21:36:32,408 pid:5365 MainThread giskard.datasets.base INFO     Casting dataframe columns from {'text': 'object'} to {'text': 'object'}
# 2025-11-24 21:36:32,416 pid:5365 MainThread giskard.utils.logging_utils INFO     Predicted dataset with shape (1, 2) executed in 0:00:00.007993
# 2025-11-24 21:36:32,418 pid:5365 MainThread giskard.datasets.base INFO     Casting dataframe columns from {'text': 'object'} to {'text': 'object'}
# 2025-11-24 21:36:32,428 pid:5365 MainThread giskard.utils.logging_utils INFO     Predicted dataset with shape (1, 2) executed in 0:00:00.009961
# 2025-11-24 21:36:32,429 pid:5365 MainThread giskard.datasets.base INFO     Casting dataframe columns from {'text': 'object'} to {'text': 'object'}
# 2025-11-24 21:36:32,435 pid:5365 MainThread giskard.utils.logging_utils INFO     Predicted dataset with shape (1, 2) executed in 0:00:00.005788
# 2025-11-24 21:36:32,436 pid:5365 MainThread giskard.datasets.base INFO     Casting dataframe columns from {'text': 'object'} to {'text': 'object'}
# 2025-11-24 21:36:32,440 pid:5365 MainThread giskard.utils.logging_utils INFO     Predicted dataset with shape (1, 2) executed in 0:00:00.003914
# 2025-11-24 21:36:32,442 pid:5365 MainThread giskard.datasets.base INFO     Casting dataframe columns from {'text': 'object'} to {'text': 'object'}
# 2025-11-24 21:36:32,448 pid:5365 MainThread giskard.utils.logging_utils INFO     Predicted dataset with shape (1, 2) executed in 0:00:00.006221
# 2025-11-24 21:36:32,449 pid:5365 MainThread giskard.datasets.base INFO     Casting dataframe columns from {'text': 'object'} to {'text': 'object'}
# 2025-11-24 21:36:32,454 pid:5365 MainThread giskard.utils.logging_utils INFO     Predicted dataset with shape (1, 2) executed in 0:00:00.005057
# 2025-11-24 21:36:32,456 pid:5365 MainThread giskard.datasets.base INFO     Casting dataframe columns from {'text': 'object'} to {'text': 'object'}
# 2025-11-24 21:36:32,462 pid:5365 MainThread giskard.utils.logging_utils INFO     Predicted dataset with shape (1, 2) executed in 0:00:00.006099
# 2025-11-24 21:36:32,463 pid:5365 MainThread giskard.datasets.base INFO     Casting dataframe columns from {'text': 'object'} to {'text': 'object'}
# 2025-11-24 21:36:32,470 pid:5365 MainThread giskard.utils.logging_utils INFO     Predicted dataset with shape (1, 2) executed in 0:00:00.007193
# 2025-11-24 21:36:32,473 pid:5365 MainThread giskard.datasets.base INFO     Casting dataframe columns from {'text': 'object'} to {'text': 'object'}
# 2025-11-24 21:36:32,481 pid:5365 MainThread giskard.utils.logging_utils INFO     Predicted dataset with shape (1, 2) executed in 0:00:00.009105
# 2025-11-24 21:36:32,483 pid:5365 MainThread giskard.datasets.base INFO     Casting dataframe columns from {'text': 'object'} to {'text': 'object'}
# 2025-11-24 21:36:32,489 pid:5365 MainThread giskard.utils.logging_utils INFO     Predicted dataset with shape (1, 2) executed in 0:00:00.005774
# 2025-11-24 21:36:32,490 pid:5365 MainThread giskard.datasets.base INFO     Casting dataframe columns from {'text': 'object'} to {'text': 'object'}
# 2025-11-24 21:36:32,494 pid:5365 MainThread giskard.utils.logging_utils INFO     Predicted dataset with shape (1, 2) executed in 0:00:00.004409
# 2025-11-24 21:36:32,497 pid:5365 MainThread giskard.datasets.base INFO     Casting dataframe columns from {'text': 'object'} to {'text': 'object'}
# 2025-11-24 21:36:32,500 pid:5365 MainThread giskard.utils.logging_utils INFO     Predicted dataset with shape (1, 2) executed in 0:00:00.004447
# 2025-11-24 21:36:32,503 pid:5365 MainThread giskard.datasets.base INFO     Casting dataframe columns from {'text': 'object'} to {'text': 'object'}
# 2025-11-24 21:36:32,508 pid:5365 MainThread giskard.utils.logging_utils INFO     Predicted dataset with shape (1, 2) executed in 0:00:00.005556
# 2025-11-24 21:36:32,510 pid:5365 MainThread giskard.datasets.base INFO     Casting dataframe columns from {'text': 'object'} to {'text': 'object'}
# 2025-11-24 21:36:32,515 pid:5365 MainThread giskard.utils.logging_utils INFO     Predicted dataset with shape (1, 2) executed in 0:00:00.005370
# 2025-11-24 21:36:32,517 pid:5365 MainThread giskard.datasets.base INFO     Casting dataframe columns from {'text': 'object'} to {'text': 'object'}
# 2025-11-24 21:36:32,520 pid:5365 MainThread giskard.utils.logging_utils INFO     Predicted dataset with shape (1, 2) executed in 0:00:00.004076
# 2025-11-24 21:36:32,522 pid:5365 MainThread giskard.datasets.base INFO     Casting dataframe columns from {'text': 'object'} to {'text': 'object'}
# 2025-11-24 21:36:32,526 pid:5365 MainThread giskard.utils.logging_utils INFO     Predicted dataset with shape (1, 2) executed in 0:00:00.004415
# 2025-11-24 21:36:32,528 pid:5365 MainThread giskard.datasets.base INFO     Casting dataframe columns from {'text': 'object'} to {'text': 'object'}
# 2025-11-24 21:36:32,533 pid:5365 MainThread giskard.utils.logging_utils INFO     Predicted dataset with shape (1, 2) executed in 0:00:00.005245
# 2025-11-24 21:36:32,535 pid:5365 MainThread giskard.datasets.base INFO     Casting dataframe columns from {'text': 'object'} to {'text': 'object'}
# 2025-11-24 21:36:32,542 pid:5365 MainThread giskard.utils.logging_utils INFO     Predicted dataset with shape (1, 2) executed in 0:00:00.007045
# 2025-11-24 21:36:32,544 pid:5365 MainThread giskard.datasets.base INFO     Casting dataframe columns from {'text': 'object'} to {'text': 'object'}
# 2025-11-24 21:36:32,547 pid:5365 MainThread giskard.utils.logging_utils INFO     Predicted dataset with shape (1, 2) executed in 0:00:00.004065
# 2025-11-24 21:36:32,549 pid:5365 MainThread giskard.datasets.base INFO     Casting dataframe columns from {'text': 'object'} to {'text': 'object'}
# 2025-11-24 21:36:32,554 pid:5365 MainThread giskard.utils.logging_utils INFO     Predicted dataset with shape (1, 2) executed in 0:00:00.005525
# 2025-11-24 21:36:32,556 pid:5365 MainThread giskard.datasets.base INFO     Casting dataframe columns from {'text': 'object'} to {'text': 'object'}
# 2025-11-24 21:36:32,560 pid:5365 MainThread giskard.utils.logging_utils INFO     Predicted dataset with shape (1, 2) executed in 0:00:00.004036
# 2025-11-24 21:36:32,562 pid:5365 MainThread giskard.datasets.base INFO     Casting dataframe columns from {'text': 'object'} to {'text': 'object'}
# 2025-11-24 21:36:32,567 pid:5365 MainThread giskard.utils.logging_utils INFO     Predicted dataset with shape (1, 2) executed in 0:00:00.005154
# 2025-11-24 21:36:32,569 pid:5365 MainThread giskard.datasets.base INFO     Casting dataframe columns from {'text': 'object'} to {'text': 'object'}
# 2025-11-24 21:36:32,577 pid:5365 MainThread giskard.utils.logging_utils INFO     Predicted dataset with shape (1, 2) executed in 0:00:00.008440
# 2025-11-24 21:36:32,578 pid:5365 MainThread giskard.datasets.base INFO     Casting dataframe columns from {'text': 'object'} to {'text': 'object'}
# 2025-11-24 21:36:32,582 pid:5365 MainThread giskard.utils.logging_utils INFO     Predicted dataset with shape (1, 2) executed in 0:00:00.003792
# 2025-11-24 21:36:32,583 pid:5365 MainThread giskard.datasets.base INFO     Casting dataframe columns from {'text': 'object'} to {'text': 'object'}
# 2025-11-24 21:36:32,586 pid:5365 MainThread giskard.utils.logging_utils INFO     Predicted dataset with shape (1, 2) executed in 0:00:00.003655
# 2025-11-24 21:36:32,588 pid:5365 MainThread giskard.datasets.base INFO     Casting dataframe columns from {'text': 'object'} to {'text': 'object'}
# 2025-11-24 21:36:32,592 pid:5365 MainThread giskard.utils.logging_utils INFO     Predicted dataset with shape (1, 2) executed in 0:00:00.004401
# 2025-11-24 21:36:32,593 pid:5365 MainThread giskard.datasets.base INFO     Casting dataframe columns from {'text': 'object'} to {'text': 'object'}
# 2025-11-24 21:36:32,600 pid:5365 MainThread giskard.utils.logging_utils INFO     Predicted dataset with shape (1, 2) executed in 0:00:00.006462
# 2025-11-24 21:36:32,601 pid:5365 MainThread giskard.datasets.base INFO     Casting dataframe columns from {'text': 'object'} to {'text': 'object'}
# 2025-11-24 21:36:32,607 pid:5365 MainThread giskard.utils.logging_utils INFO     Predicted dataset with shape (1, 2) executed in 0:00:00.006425
# 2025-11-24 21:36:32,609 pid:5365 MainThread giskard.datasets.base INFO     Casting dataframe columns from {'text': 'object'} to {'text': 'object'}
# 2025-11-24 21:36:32,615 pid:5365 MainThread giskard.utils.logging_utils INFO     Predicted dataset with shape (1, 2) executed in 0:00:00.006722
# 2025-11-24 21:36:32,617 pid:5365 MainThread giskard.datasets.base INFO     Casting dataframe columns from {'text': 'object'} to {'text': 'object'}
# 2025-11-24 21:36:32,623 pid:5365 MainThread giskard.utils.logging_utils INFO     Predicted dataset with shape (1, 2) executed in 0:00:00.006454
# 2025-11-24 21:36:32,624 pid:5365 MainThread giskard.datasets.base INFO     Casting dataframe columns from {'text': 'object'} to {'text': 'object'}
# 2025-11-24 21:36:32,628 pid:5365 MainThread giskard.utils.logging_utils INFO     Predicted dataset with shape (1, 2) executed in 0:00:00.004189
# 2025-11-24 21:36:32,629 pid:5365 MainThread giskard.datasets.base INFO     Casting dataframe columns from {'text': 'object'} to {'text': 'object'}
# 2025-11-24 21:36:32,636 pid:5365 MainThread giskard.utils.logging_utils INFO     Predicted dataset with shape (1, 2) executed in 0:00:00.006585
# 2025-11-24 21:36:32,637 pid:5365 MainThread giskard.datasets.base INFO     Casting dataframe columns from {'text': 'object'} to {'text': 'object'}
# 2025-11-24 21:36:32,643 pid:5365 MainThread giskard.utils.logging_utils INFO     Predicted dataset with shape (1, 2) executed in 0:00:00.006687
# 2025-11-24 21:36:32,645 pid:5365 MainThread giskard.datasets.base INFO     Casting dataframe columns from {'text': 'object'} to {'text': 'object'}
# 2025-11-24 21:36:32,651 pid:5365 MainThread giskard.utils.logging_utils INFO     Predicted dataset with shape (1, 2) executed in 0:00:00.006620
# 2025-11-24 21:36:32,653 pid:5365 MainThread giskard.datasets.base INFO     Casting dataframe columns from {'text': 'object'} to {'text': 'object'}
# 2025-11-24 21:36:32,657 pid:5365 MainThread giskard.utils.logging_utils INFO     Predicted dataset with shape (1, 2) executed in 0:00:00.004650
# 2025-11-24 21:36:32,658 pid:5365 MainThread giskard.datasets.base INFO     Casting dataframe columns from {'text': 'object'} to {'text': 'object'}
# 2025-11-24 21:36:32,665 pid:5365 MainThread giskard.utils.logging_utils INFO     Predicted dataset with shape (1, 2) executed in 0:00:00.006560
# 2025-11-24 21:36:32,666 pid:5365 MainThread giskard.datasets.base INFO     Casting dataframe columns from {'text': 'object'} to {'text': 'object'}
# 2025-11-24 21:36:32,672 pid:5365 MainThread giskard.utils.logging_utils INFO     Predicted dataset with shape (1, 2) executed in 0:00:00.006843
# 2025-11-24 21:36:32,674 pid:5365 MainThread giskard.datasets.base INFO     Casting dataframe columns from {'text': 'object'} to {'text': 'object'}
# 2025-11-24 21:36:32,678 pid:5365 MainThread giskard.utils.logging_utils INFO     Predicted dataset with shape (1, 2) executed in 0:00:00.004097
# 2025-11-24 21:36:32,679 pid:5365 MainThread giskard.datasets.base INFO     Casting dataframe columns from {'text': 'object'} to {'text': 'object'}
# 2025-11-24 21:36:32,685 pid:5365 MainThread giskard.utils.logging_utils INFO     Predicted dataset with shape (1, 2) executed in 0:00:00.006591
# 2025-11-24 21:36:32,687 pid:5365 MainThread giskard.datasets.base INFO     Casting dataframe columns from {'text': 'object'} to {'text': 'object'}
# 2025-11-24 21:36:32,693 pid:5365 MainThread giskard.utils.logging_utils INFO     Predicted dataset with shape (1, 2) executed in 0:00:00.006591
# 2025-11-24 21:36:32,695 pid:5365 MainThread giskard.datasets.base INFO     Casting dataframe columns from {'text': 'object'} to {'text': 'object'}
# 2025-11-24 21:36:32,699 pid:5365 MainThread giskard.utils.logging_utils INFO     Predicted dataset with shape (1, 2) executed in 0:00:00.004228
# 2025-11-24 21:36:32,700 pid:5365 MainThread giskard.datasets.base INFO     Casting dataframe columns from {'text': 'object'} to {'text': 'object'}
# 2025-11-24 21:36:32,706 pid:5365 MainThread giskard.utils.logging_utils INFO     Predicted dataset with shape (1, 2) executed in 0:00:00.006165
# 2025-11-24 21:36:32,707 pid:5365 MainThread giskard.datasets.base INFO     Casting dataframe columns from {'text': 'object'} to {'text': 'object'}
# 2025-11-24 21:36:32,714 pid:5365 MainThread giskard.utils.logging_utils INFO     Predicted dataset with shape (1, 2) executed in 0:00:00.006748
# 2025-11-24 21:36:32,715 pid:5365 MainThread giskard.scanner.logger INFO     EthicalBiasDetector: Running with transformations=['Switch Gender', 'Switch Religion', 'Switch countries from high- to low-income and vice versa'] threshold=None output_sensitivity=None num_samples=None
# 2025-11-24 21:36:55,920 pid:5365 MainThread giskard.datasets.base INFO     Casting dataframe columns from {'text': 'object'} to {'text': 'object'}
# 2025-11-24 21:36:55,921 pid:5365 MainThread giskard.utils.logging_utils INFO     Predicted dataset with shape (1000, 2) executed in 0:00:00.005520
# 2025-11-24 21:36:55,926 pid:5365 MainThread giskard.datasets.base INFO     Casting dataframe columns from {'text': 'object'} to {'text': 'object'}
# 2025-11-24 21:36:57,604 pid:5365 MainThread giskard.utils.logging_utils INFO     Predicted dataset with shape (1000, 2) executed in 0:00:01.682303
# 2025-11-24 21:36:57,604 pid:5365 MainThread giskard.scanner.logger INFO     EthicalBiasDetector: Testing `text` for perturbation `Switch Gender`	Fail rate: 0.000
# 2025-11-24 21:37:22,635 pid:5365 MainThread giskard.datasets.base INFO     Casting dataframe columns from {'text': 'object'} to {'text': 'object'}
# 2025-11-24 21:37:22,636 pid:5365 MainThread giskard.utils.logging_utils INFO     Predicted dataset with shape (37, 2) executed in 0:00:00.002259
# 2025-11-24 21:37:22,638 pid:5365 MainThread giskard.datasets.base INFO     Casting dataframe columns from {'text': 'object'} to {'text': 'object'}
# 2025-11-24 21:37:22,718 pid:5365 MainThread giskard.utils.logging_utils INFO     Predicted dataset with shape (37, 2) executed in 0:00:00.081872
# 2025-11-24 21:37:22,718 pid:5365 MainThread giskard.scanner.logger INFO     EthicalBiasDetector: Testing `text` for perturbation `Switch Religion`	Fail rate: 0.000
# 2025-11-24 21:38:26,747 pid:5365 MainThread giskard.datasets.base INFO     Casting dataframe columns from {'text': 'object'} to {'text': 'object'}
# 2025-11-24 21:38:26,748 pid:5365 MainThread giskard.utils.logging_utils INFO     Predicted dataset with shape (395, 2) executed in 0:00:00.003947
# 2025-11-24 21:38:26,751 pid:5365 MainThread giskard.datasets.base INFO     Casting dataframe columns from {'text': 'object'} to {'text': 'object'}
# 2025-11-24 21:38:27,426 pid:5365 MainThread giskard.utils.logging_utils INFO     Predicted dataset with shape (395, 2) executed in 0:00:00.678123
# 2025-11-24 21:38:27,427 pid:5365 MainThread giskard.scanner.logger INFO     EthicalBiasDetector: Testing `text` for perturbation `Switch countries from high- to low-income and vice versa`	Fail rate: 0.000
# 2025-11-24 21:38:27,428 pid:5365 MainThread giskard.scanner.logger INFO     TextPerturbationDetector: Running with transformations=['Transform to uppercase', 'Transform to lowercase', 'Transform to title case', 'Add typos', 'Punctuation Removal', 'Transform numbers to words', 'Accent Removal'] threshold=None output_sensitivity=None num_samples=None
# 2025-11-24 21:38:27,444 pid:5365 MainThread giskard.datasets.base INFO     Casting dataframe columns from {'text': 'object'} to {'text': 'object'}
# 2025-11-24 21:38:27,445 pid:5365 MainThread giskard.utils.logging_utils INFO     Predicted dataset with shape (1000, 2) executed in 0:00:00.004391
# 2025-11-24 21:38:27,448 pid:5365 MainThread giskard.datasets.base INFO     Casting dataframe columns from {'text': 'object'} to {'text': 'object'}
# 2025-11-24 21:38:29,025 pid:5365 MainThread giskard.utils.logging_utils INFO     Predicted dataset with shape (1000, 2) executed in 0:00:01.579875
# 2025-11-24 21:38:29,025 pid:5365 MainThread giskard.scanner.logger INFO     TextPerturbationDetector: Testing `text` for perturbation `Transform to uppercase`	Fail rate: 0.000
# 2025-11-24 21:38:29,040 pid:5365 MainThread giskard.datasets.base INFO     Casting dataframe columns from {'text': 'object'} to {'text': 'object'}
# 2025-11-24 21:38:29,041 pid:5365 MainThread giskard.utils.logging_utils INFO     Predicted dataset with shape (1000, 2) executed in 0:00:00.004567
# 2025-11-24 21:38:29,044 pid:5365 MainThread giskard.datasets.base INFO     Casting dataframe columns from {'text': 'object'} to {'text': 'object'}
# 2025-11-24 21:38:30,644 pid:5365 MainThread giskard.utils.logging_utils INFO     Predicted dataset with shape (1000, 2) executed in 0:00:01.602795
# 2025-11-24 21:38:30,644 pid:5365 MainThread giskard.scanner.logger INFO     TextPerturbationDetector: Testing `text` for perturbation `Transform to lowercase`	Fail rate: 0.000
# 2025-11-24 21:38:30,675 pid:5365 MainThread giskard.datasets.base INFO     Casting dataframe columns from {'text': 'object'} to {'text': 'object'}
# 2025-11-24 21:38:30,676 pid:5365 MainThread giskard.utils.logging_utils INFO     Predicted dataset with shape (1000, 2) executed in 0:00:00.004729
# 2025-11-24 21:38:30,680 pid:5365 MainThread giskard.datasets.base INFO     Casting dataframe columns from {'text': 'object'} to {'text': 'object'}
# 2025-11-24 21:38:32,275 pid:5365 MainThread giskard.utils.logging_utils INFO     Predicted dataset with shape (1000, 2) executed in 0:00:01.598596
# 2025-11-24 21:38:32,275 pid:5365 MainThread giskard.scanner.logger INFO     TextPerturbationDetector: Testing `text` for perturbation `Transform to title case`	Fail rate: 0.000
# 2025-11-24 21:38:33,285 pid:5365 MainThread giskard.datasets.base INFO     Casting dataframe columns from {'text': 'object'} to {'text': 'object'}
# 2025-11-24 21:38:33,286 pid:5365 MainThread giskard.utils.logging_utils INFO     Predicted dataset with shape (1000, 2) executed in 0:00:00.004596
# 2025-11-24 21:38:33,289 pid:5365 MainThread giskard.datasets.base INFO     Casting dataframe columns from {'text': 'object'} to {'text': 'object'}
# 2025-11-24 21:38:34,888 pid:5365 MainThread giskard.utils.logging_utils INFO     Predicted dataset with shape (1000, 2) executed in 0:00:01.602271
# 2025-11-24 21:38:34,888 pid:5365 MainThread giskard.scanner.logger INFO     TextPerturbationDetector: Testing `text` for perturbation `Add typos`	Fail rate: 0.000
# 2025-11-24 21:38:58,058 pid:5365 MainThread giskard.scanner.logger ERROR    Detector TextPerturbationDetector failed with error: 'Num2Word_VI' object has no attribute 'str_to_number'
# Traceback (most recent call last):
#   File "/home/patryk/Documents/umisi/sem2/Solutions/lab06/.venv/lib/python3.11/site-packages/giskard/scanner/scanner.py", line 162, in _run_detectors
#     detected_issues = detector.run(model, dataset, features=features)
#                       ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/home/patryk/Documents/umisi/sem2/Solutions/lab06/.venv/lib/python3.11/site-packages/giskard/scanner/robustness/base_detector.py", line 327, in run
#     issues.extend(self._detect_issues(model, dataset, transformation, selected_features))
#                   ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/home/patryk/Documents/umisi/sem2/Solutions/lab06/.venv/lib/python3.11/site-packages/giskard/scanner/robustness/base_detector.py", line 196, in _detect_issues
#     transformed = dataset.transform(transformation_fn)
#                   ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/home/patryk/Documents/umisi/sem2/Solutions/lab06/.venv/lib/python3.11/site-packages/pydantic/_internal/_validate_call.py", line 39, in wrapper_function
#     return wrapper(*args, **kwargs)
#            ^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/home/patryk/Documents/umisi/sem2/Solutions/lab06/.venv/lib/python3.11/site-packages/pydantic/_internal/_validate_call.py", line 136, in __call__
#     res = self.__pydantic_validator__.validate_python(pydantic_core.ArgsKwargs(args, kwargs))
#           ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/home/patryk/Documents/umisi/sem2/Solutions/lab06/.venv/lib/python3.11/site-packages/giskard/datasets/base/__init__.py", line 376, in transform
#     return self.data_processor.add_step(transformation_function).apply(self, apply_only_last=True)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/home/patryk/Documents/umisi/sem2/Solutions/lab06/.venv/lib/python3.11/site-packages/giskard/datasets/base/__init__.py", line 85, in apply
#     df = step.execute(ds) if getattr(step, "needs_dataset", False) else step.execute(ds.df)
#          ^^^^^^^^^^^^^^^^
#   File "/home/patryk/Documents/umisi/sem2/Solutions/lab06/.venv/lib/python3.11/site-packages/giskard/scanner/robustness/text_transformations.py", line 212, in execute
#     dataset.df.loc[feature_data.index, self.column] = feature_data.apply(self.make_perturbation, axis=1)
#                                                       ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/home/patryk/Documents/umisi/sem2/Solutions/lab06/.venv/lib/python3.11/site-packages/pandas/core/frame.py", line 10374, in apply
#     return op.apply().__finalize__(self, method="apply")
#            ^^^^^^^^^^
#   File "/home/patryk/Documents/umisi/sem2/Solutions/lab06/.venv/lib/python3.11/site-packages/pandas/core/apply.py", line 916, in apply
#     return self.apply_standard()
#            ^^^^^^^^^^^^^^^^^^^^^
#   File "/home/patryk/Documents/umisi/sem2/Solutions/lab06/.venv/lib/python3.11/site-packages/pandas/core/apply.py", line 1063, in apply_standard
#     results, res_index = self.apply_series_generator()
#                          ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/home/patryk/Documents/umisi/sem2/Solutions/lab06/.venv/lib/python3.11/site-packages/pandas/core/apply.py", line 1081, in apply_series_generator
#     results[i] = self.func(v, *self.args, **self.kwargs)
#                  ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/home/patryk/Documents/umisi/sem2/Solutions/lab06/.venv/lib/python3.11/site-packages/giskard/scanner/robustness/text_transformations.py", line 280, in make_perturbation
#     return self._regex.sub(lambda x: num2words(x.group(), lang=lang), value)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/home/patryk/Documents/umisi/sem2/Solutions/lab06/.venv/lib/python3.11/site-packages/giskard/scanner/robustness/text_transformations.py", line 280, in <lambda>
#     return self._regex.sub(lambda x: num2words(x.group(), lang=lang), value)
#                                      ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/home/patryk/Documents/umisi/sem2/Solutions/lab06/.venv/lib/python3.11/site-packages/num2words/__init__.py", line 102, in num2words
#     number = converter.str_to_number(number)
#              ^^^^^^^^^^^^^^^^^^^^^^^
# AttributeError: 'Num2Word_VI' object has no attribute 'str_to_number'
# 2025-11-24 21:38:58,060 pid:5365 MainThread giskard.scanner.logger INFO     NumericalPerturbationDetector: Running with transformations=['Multiply by factor', 'Multiply by factor', 'Add Gaussian noise'] threshold=None output_sensitivity=None num_samples=None
# 2025-11-24 21:38:58,061 pid:5365 MainThread giskard.scanner.logger INFO     SpuriousCorrelationDetector: Running
# 2025-11-24 21:38:58,079 pid:5365 MainThread giskard.datasets.base INFO     Casting dataframe columns from {'text': 'object'} to {'text': 'object'}
# 2025-11-24 21:38:58,085 pid:5365 MainThread giskard.utils.logging_utils INFO     Predicted dataset with shape (29913, 2) executed in 0:00:00.023102
# 2025-11-24 21:39:20,693 pid:5365 MainThread giskard.datasets.base INFO     Your 'pandas.DataFrame' is successfully wrapped by Giskard's 'Dataset' wrapper class.
# 2025-11-24 21:39:21,070 pid:5365 MainThread giskard.scanner.logger INFO     SpuriousCorrelationDetector: `charset(text)` == "ascii"	Association = nan
# 2025-11-24 21:39:22,375 pid:5365 MainThread giskard.scanner.logger INFO     SpuriousCorrelationDetector: `text` contains "small"	Association = nan
# 2025-11-24 21:39:23,391 pid:5365 MainThread giskard.scanner.logger INFO     SpuriousCorrelationDetector: `text` contains "great"	Association = nan
# 2025-11-24 21:39:24,774 pid:5365 MainThread giskard.scanner.logger INFO     SpuriousCorrelationDetector: `text` contains "bed"	Association = nan
# 2025-11-24 21:39:27,055 pid:5365 MainThread giskard.scanner.logger INFO     SpuriousCorrelationDetector: `text` contains "location"	Association = nan
# 2025-11-24 21:39:27,483 pid:5365 MainThread giskard.scanner.logger INFO     SpuriousCorrelationDetector: `text` contains "breakfast"	Association = nan
# 2025-11-24 21:39:32,031 pid:5365 MainThread giskard.scanner.logger INFO     SpuriousCorrelationDetector: `text` contains "nice"	Association = nan
# 2025-11-24 21:39:39,061 pid:5365 MainThread giskard.scanner.logger INFO     SpuriousCorrelationDetector: `text` contains "comfortable"	Association = nan
# 2025-11-24 21:39:42,888 pid:5365 MainThread giskard.scanner.logger INFO     SpuriousCorrelationDetector: `text` contains "clean"	Association = nan
# 2025-11-24 21:39:45,473 pid:5365 MainThread giskard.scanner.logger INFO     SpuriousCorrelationDetector: `text` contains "service"	Association = nan
# 2025-11-24 21:39:47,591 pid:5365 MainThread giskard.scanner.logger INFO     SpuriousCorrelationDetector: `text` contains "hotel"	Association = nan
# 2025-11-24 21:39:49,528 pid:5365 MainThread giskard.scanner.logger INFO     SpuriousCorrelationDetector: `text` contains "good"	Association = nan
# 2025-11-24 21:39:54,460 pid:5365 MainThread giskard.scanner.logger INFO     SpuriousCorrelationDetector: `text` contains "stay"	Association = nan
# 2025-11-24 21:39:54,628 pid:5365 MainThread giskard.scanner.logger INFO     SpuriousCorrelationDetector: `text` contains "room"	Association = nan
# 2025-11-24 21:39:56,401 pid:5365 MainThread giskard.scanner.logger INFO     SpuriousCorrelationDetector: `text` contains "rooms"	Association = nan
# 2025-11-24 21:39:56,710 pid:5365 MainThread giskard.scanner.logger INFO     SpuriousCorrelationDetector: `text` contains "excellent"	Association = nan
# 2025-11-24 21:39:57,094 pid:5365 MainThread giskard.scanner.logger INFO     SpuriousCorrelationDetector: `text` contains "friendly"	Association = nan
# 2025-11-24 21:40:04,435 pid:5365 MainThread giskard.scanner.logger INFO     OverconfidenceDetector: Running
# 2025-11-24 21:40:04,436 pid:5365 MainThread giskard.scanner.logger INFO     OverconfidenceDetector: Calculating loss
# 2025-11-24 21:40:04,474 pid:5365 MainThread giskard.datasets.base INFO     Casting dataframe columns from {'text': 'object'} to {'text': 'object'}
# 2025-11-24 21:40:04,480 pid:5365 MainThread giskard.utils.logging_utils INFO     Predicted dataset with shape (29913, 2) executed in 0:00:00.043232
# 2025-11-24 21:40:04,484 pid:5365 MainThread giskard.scanner.logger INFO     OverconfidenceDetector: Loss calculated (took 0:00:00.047782)
# 2025-11-24 21:40:04,484 pid:5365 MainThread giskard.scanner.logger INFO     OverconfidenceDetector: Finding data slices
# 2025-11-24 21:41:03,885 pid:5365 MainThread giskard.scanner.logger INFO     OverconfidenceDetector: 8 slices found (took 0:00:59.400582)
# 2025-11-24 21:41:03,885 pid:5365 MainThread giskard.scanner.logger INFO     OverconfidenceDetector: Analyzing issues
# 2025-11-24 21:41:03,903 pid:5365 MainThread giskard.datasets.base INFO     Your 'pandas.DataFrame' is successfully wrapped by Giskard's 'Dataset' wrapper class.
# 2025-11-24 21:41:03,904 pid:5365 MainThread giskard.scanner.logger INFO     OverconfidenceDetector: Using overconfidence threshold = 0.5
# 2025-11-24 21:41:04,119 pid:5365 MainThread giskard.scanner.logger INFO     OverconfidenceDetector: 0 issues found (took 0:00:00.233835)
# 2025-11-24 21:41:04,120 pid:5365 MainThread giskard.scanner.logger INFO     UnderconfidenceDetector: Running
# 2025-11-24 21:41:04,120 pid:5365 MainThread giskard.scanner.logger INFO     UnderconfidenceDetector: Calculating loss
# 2025-11-24 21:41:04,140 pid:5365 MainThread giskard.datasets.base INFO     Casting dataframe columns from {'text': 'object'} to {'text': 'object'}
# 2025-11-24 21:41:04,145 pid:5365 MainThread giskard.utils.logging_utils INFO     Predicted dataset with shape (29913, 2) executed in 0:00:00.023844
# 2025-11-24 21:41:04,146 pid:5365 MainThread giskard.scanner.logger INFO     UnderconfidenceDetector: Loss calculated (took 0:00:00.025443)
# 2025-11-24 21:41:04,147 pid:5365 MainThread giskard.scanner.logger INFO     UnderconfidenceDetector: Finding data slices
# 2025-11-24 21:43:05,468 pid:5365 MainThread giskard.scanner.logger INFO     UnderconfidenceDetector: 24 slices found (took 0:02:01.321484)
# ...
# 2025-11-24 21:45:17,334 pid:5365 MainThread giskard.scanner.logger INFO     PerformanceBiasDetector: Testing slice `text` contains "rooms"	Precision = 0.553 (global 0.551) Δm = 0.005	is_issue = False
# 2025-11-24 21:45:17,374 pid:5365 MainThread giskard.scanner.logger INFO     PerformanceBiasDetector: Testing slice `text` contains "room"	Precision = 0.489 (global 0.551) Δm = -0.112	is_issue = True
# 2025-11-24 21:45:17,467 pid:5365 MainThread giskard.scanner.logger INFO     PerformanceBiasDetector: Testing slice `text` contains "great"	Precision = 0.895 (global 0.551) Δm = 0.625	is_issue = False
# 2025-11-24 21:45:17,512 pid:5365 MainThread giskard.scanner.logger INFO     PerformanceBiasDetector: Testing slice `text` contains "bed"	Precision = 0.642 (global 0.551) Δm = 0.165	is_issue = False
# 2025-11-24 21:45:17,557 pid:5365 MainThread giskard.scanner.logger INFO     PerformanceBiasDetector: Testing slice `text` contains "nice"	Precision = 0.860 (global 0.551) Δm = 0.561	is_issue = False
# 2025-11-24 21:45:17,607 pid:5365 MainThread giskard.scanner.logger INFO     PerformanceBiasDetector: Testing slice `text` contains "service"	Precision = 0.573 (global 0.551) Δm = 0.041	is_issue = False
# 2025-11-24 21:45:17,651 pid:5365 MainThread giskard.scanner.logger INFO     PerformanceBiasDetector: Testing slice `text` contains "excellent"	Precision = 0.943 (global 0.551) Δm = 0.714	is_issue = False
# 2025-11-24 21:45:17,695 pid:5365 MainThread giskard.scanner.logger INFO     PerformanceBiasDetector: Testing slice `text` contains "friendly"	Precision = 0.928 (global 0.551) Δm = 0.686	is_issue = False
# 2025-11-24 21:45:17,745 pid:5365 MainThread giskard.scanner.logger INFO     PerformanceBiasDetector: Testing slice `text` contains "small"	Precision = 0.191 (global 0.551) Δm = -0.653	is_issue = True
# 2025-11-24 21:45:17,839 pid:5365 MainThread giskard.scanner.logger INFO     PerformanceBiasDetector: Testing slice `text` contains "hotel"	Precision = 0.641 (global 0.551) Δm = 0.165	is_issue = False
# 2025-11-24 21:45:17,883 pid:5365 MainThread giskard.scanner.logger INFO     PerformanceBiasDetector: Testing slice `text` contains "good"	Precision = 0.821 (global 0.551) Δm = 0.492	is_issue = False
# 2025-11-24 21:45:17,928 pid:5365 MainThread giskard.scanner.logger INFO     PerformanceBiasDetector: Testing slice `text` contains "location"	Recall = 1.000 (global 1.000) Δm = 0.000	is_issue = False
# 2025-11-24 21:45:17,973 pid:5365 MainThread giskard.scanner.logger INFO     PerformanceBiasDetector: Testing slice `text` contains "breakfast"	Recall = 1.000 (global 1.000) Δm = 0.000	is_issue = False
# 2025-11-24 21:45:18,017 pid:5365 MainThread giskard.scanner.logger INFO     PerformanceBiasDetector: Testing slice `text` contains "comfortable"	Recall = 1.000 (global 1.000) Δm = 0.000	is_issue = False
# 2025-11-24 21:45:18,064 pid:5365 MainThread giskard.scanner.logger INFO     PerformanceBiasDetector: Testing slice `text` contains "clean"	Recall = 1.000 (global 1.000) Δm = 0.000	is_issue = False
# 2025-11-24 21:45:18,115 pid:5365 MainThread giskard.scanner.logger INFO     PerformanceBiasDetector: Testing slice `text` contains "stay"	Recall = 1.000 (global 1.000) Δm = 0.000	is_issue = False
# 2025-11-24 21:45:18,161 pid:5365 MainThread giskard.scanner.logger INFO     PerformanceBiasDetector: Testing slice `text` contains "rooms"	Recall = 1.000 (global 1.000) Δm = 0.000	is_issue = False
# 2025-11-24 21:45:18,201 pid:5365 MainThread giskard.scanner.logger INFO     PerformanceBiasDetector: Testing slice `text` contains "room"	Recall = 1.000 (global 1.000) Δm = 0.000	is_issue = False
# 2025-11-24 21:45:18,246 pid:5365 MainThread giskard.scanner.logger INFO     PerformanceBiasDetector: Testing slice `text` contains "great"	Recall = 1.000 (global 1.000) Δm = 0.000	is_issue = False
# 2025-11-24 21:45:18,292 pid:5365 MainThread giskard.scanner.logger INFO     PerformanceBiasDetector: Testing slice `text` contains "bed"	Recall = 1.000 (global 1.000) Δm = 0.000	is_issue = False
# 2025-11-24 21:45:18,340 pid:5365 MainThread giskard.scanner.logger INFO     PerformanceBiasDetector: Testing slice `text` contains "nice"	Recall = 1.000 (global 1.000) Δm = 0.000	is_issue = False
# 2025-11-24 21:45:18,392 pid:5365 MainThread giskard.scanner.logger INFO     PerformanceBiasDetector: Testing slice `text` contains "service"	Recall = 1.000 (global 1.000) Δm = 0.000	is_issue = False
# 2025-11-24 21:45:18,435 pid:5365 MainThread giskard.scanner.logger INFO     PerformanceBiasDetector: Testing slice `text` contains "excellent"	Recall = 1.000 (global 1.000) Δm = 0.000	is_issue = False
# 2025-11-24 21:45:18,482 pid:5365 MainThread giskard.scanner.logger INFO     PerformanceBiasDetector: Testing slice `text` contains "friendly"	Recall = 1.000 (global 1.000) Δm = 0.000	is_issue = False
# 2025-11-24 21:45:18,532 pid:5365 MainThread giskard.scanner.logger INFO     PerformanceBiasDetector: Testing slice `text` contains "small"	Recall = 1.000 (global 1.000) Δm = 0.000	is_issue = False
# 2025-11-24 21:45:18,577 pid:5365 MainThread giskard.scanner.logger INFO     PerformanceBiasDetector: Testing slice `text` contains "hotel"	Recall = 1.000 (global 1.000) Δm = 0.000	is_issue = False
# 2025-11-24 21:45:18,621 pid:5365 MainThread giskard.scanner.logger INFO     PerformanceBiasDetector: Testing slice `text` contains "good"	Recall = 1.000 (global 1.000) Δm = 0.000	is_issue = False
# 2025-11-24 21:45:18,664 pid:5365 MainThread giskard.scanner.logger INFO     PerformanceBiasDetector: Testing slice `text` contains "location"	Accuracy = 0.926 (global 0.551) Δm = 0.682	is_issue = False
# 2025-11-24 21:45:18,707 pid:5365 MainThread giskard.scanner.logger INFO     PerformanceBiasDetector: Testing slice `text` contains "breakfast"	Accuracy = 0.603 (global 0.551) Δm = 0.096	is_issue = False
# 2025-11-24 21:45:18,750 pid:5365 MainThread giskard.scanner.logger INFO     PerformanceBiasDetector: Testing slice `text` contains "comfortable"	Accuracy = 0.899 (global 0.551) Δm = 0.633	is_issue = False
# 2025-11-24 21:45:18,794 pid:5365 MainThread giskard.scanner.logger INFO     PerformanceBiasDetector: Testing slice `text` contains "clean"	Accuracy = 0.879 (global 0.551) Δm = 0.597	is_issue = False
# 2025-11-24 21:45:18,843 pid:5365 MainThread giskard.scanner.logger INFO     PerformanceBiasDetector: Testing slice `text` contains "stay"	Accuracy = 0.635 (global 0.551) Δm = 0.154	is_issue = False
# 2025-11-24 21:45:18,887 pid:5365 MainThread giskard.scanner.logger INFO     PerformanceBiasDetector: Testing slice `text` contains "rooms"	Accuracy = 0.553 (global 0.551) Δm = 0.005	is_issue = False
# 2025-11-24 21:45:18,925 pid:5365 MainThread giskard.scanner.logger INFO     PerformanceBiasDetector: Testing slice `text` contains "room"	Accuracy = 0.489 (global 0.551) Δm = -0.112	is_issue = True
# 2025-11-24 21:45:19,017 pid:5365 MainThread giskard.scanner.logger INFO     PerformanceBiasDetector: Testing slice `text` contains "great"	Accuracy = 0.895 (global 0.551) Δm = 0.625	is_issue = False
# 2025-11-24 21:45:19,061 pid:5365 MainThread giskard.scanner.logger INFO     PerformanceBiasDetector: Testing slice `text` contains "bed"	Accuracy = 0.642 (global 0.551) Δm = 0.165	is_issue = False
# 2025-11-24 21:45:19,105 pid:5365 MainThread giskard.scanner.logger INFO     PerformanceBiasDetector: Testing slice `text` contains "nice"	Accuracy = 0.860 (global 0.551) Δm = 0.561	is_issue = False
# 2025-11-24 21:45:19,155 pid:5365 MainThread giskard.scanner.logger INFO     PerformanceBiasDetector: Testing slice `text` contains "service"	Accuracy = 0.573 (global 0.551) Δm = 0.041	is_issue = False
# 2025-11-24 21:45:19,198 pid:5365 MainThread giskard.scanner.logger INFO     PerformanceBiasDetector: Testing slice `text` contains "excellent"	Accuracy = 0.943 (global 0.551) Δm = 0.714	is_issue = False
# 2025-11-24 21:45:19,241 pid:5365 MainThread giskard.scanner.logger INFO     PerformanceBiasDetector: Testing slice `text` contains "friendly"	Accuracy = 0.928 (global 0.551) Δm = 0.686	is_issue = False
# 2025-11-24 21:45:19,290 pid:5365 MainThread giskard.scanner.logger INFO     PerformanceBiasDetector: Testing slice `text` contains "small"	Accuracy = 0.191 (global 0.551) Δm = -0.653	is_issue = True
# 2025-11-24 21:45:19,382 pid:5365 MainThread giskard.scanner.logger INFO     PerformanceBiasDetector: Testing slice `text` contains "hotel"	Accuracy = 0.641 (global 0.551) Δm = 0.165	is_issue = False
# 2025-11-24 21:45:19,424 pid:5365 MainThread giskard.scanner.logger INFO     PerformanceBiasDetector: Testing slice `text` contains "good"	Accuracy = 0.821 (global 0.551) Δm = 0.492	is_issue = False
# 2025-11-24 21:45:19,425 pid:5365 MainThread giskard.scanner.logger INFO     PerformanceBiasDetector: 2 issues found (took 0:00:02.400392)
# <iframe id="scan-140557697983312" srcdoc="&lt;!doctype html&gt;
# &lt;html lang=&quot;en&quot;&gt;
#
# &lt;head&gt;
#     &lt;title&gt;Giskard Scan Results&lt;/title&gt;
#     &lt;base target=&quot;_blank&quot;&gt;
#     &lt;meta charset=&quot;utf-8&quot;&gt;
#
# &lt;style&gt;pre code.hljs{display:block;overflow-x:auto;padding:1em}code.hljs{padding:3px 5px}
# /*!
#   Theme: GitHub Dark
#   Description: Dark theme as seen on github.com
#   Author: github.com
#   Maintainer: @Hirse
#   Updated: 2021-05-15
#
#   Outdated base version: https://github.com/primer/github-syntax-dark
#   Current colors taken from GitHub&#x27;s CSS
# */.hljs{background:#0d1117;color:#c9d1d9}.hljs-doctag,.hljs-keyword,.hljs-meta .hljs-keyword,.hljs-template-tag,.hljs-template-variable,.hljs-type,.hljs-variable.language_{color:#ff7b72}.hljs-title,.hljs-title.class_,.hljs-title.class_.inherited__,.hljs-title.function_{color:#d2a8ff}.hljs-attr,.hljs-attribute,.hljs-literal,.hljs-meta,.hljs-number,.hljs-operator,.hljs-selector-attr,.hljs-selector-class,.hljs-selector-id,.hljs-variable{color:#79c0ff}.hljs-meta .hljs-string,.hljs-regexp,.hljs-string{color:#a5d6ff}.hljs-built_in,.hljs-symbol{color:#ffa657}.hljs-code,.hljs-comment,.hljs-formula{color:#8b949e}.hljs-name,.hljs-quote,.hljs-selector-pseudo,.hljs-selector-tag{color:#7ee787}.hljs-subst{color:#c9d1d9}.hljs-section{color:#1f6feb;font-weight:700}.hljs-bullet{color:#f2cc60}.hljs-emphasis{color:#c9d1d9;font-style:italic}.hljs-strong{color:#c9d1d9;font-weight:700}.hljs-addition{background-color:#033a16;color:#aff5b4}.hljs-deletion{background-color:#67060c;color:#ffdcd7}.hljs-copy-wrapper{overflow:hidden;position:relative}.hljs-copy-button:focus,.hljs-copy-wrapper:hover .hljs-copy-button{transform:translateX(0)}.hljs-copy-button{background-color:#2d2b57;background-color:var(--hljs-theme-background);background-image:url(&#x27;data:image/svg+xml;charset=utf-8,&lt;svg xmlns=&quot;http://www.w3.org/2000/svg&quot; width=&quot;16&quot; height=&quot;16&quot; fill=&quot;none&quot; viewBox=&quot;0 0 24 24&quot;&gt;&lt;path fill=&quot;%23fff&quot; fill-rule=&quot;evenodd&quot; d=&quot;M6 5a1 1 0 0 0-1 1v14a1 1 0 0 0 1 1h12a1 1 0 0 0 1-1V6a1 1 0 0 0-1-1h-2a1 1 0 1 1 0-2h2a3 3 0 0 1 3 3v14a3 3 0 0 1-3 3H6a3 3 0 0 1-3-3V6a3 3 0 0 1 3-3h2a1 1 0 0 1 0 2H6Z&quot; clip-rule=&quot;evenodd&quot;/&gt;&lt;path fill=&quot;%23fff&quot; fill-rule=&quot;evenodd&quot; d=&quot;M7 3a2 2 0 0 1 2-2h6a2 2 0 0 1 2 2v2a2 2 0 0 1-2 2H9a2 2 0 0 1-2-2V3Zm8 0H9v2h6V3Z&quot; clip-rule=&quot;evenodd&quot;/&gt;&lt;/svg&gt;&#x27;);background-position:50%;background-repeat:no-repeat;border:1px solid #ffffff22;border-radius:.25rem;color:#fff;height:2rem;position:absolute;right:1em;text-indent:-9999px;top:1em;transition:background-color .2s ease,transform .2s ease-out;width:2rem}.hljs-copy-button:hover{border-color:#ffffff44}.hljs-copy-button:active{border-color:#ffffff66}.hljs-copy-button[data-copied=true]{background-image:none;text-indent:0;width:auto}@media (prefers-reduced-motion){.hljs-copy-button{transition:none}}.hljs-copy-alert{clip:rect(0 0 0 0);-webkit-clip-path:inset(50%);clip-path:inset(50%);height:1px;overflow:hidden;position:absolute;white-space:nowrap;width:1px}
# /*! tailwindcss v3.3.2 | MIT License | https://tailwindcss.com*/*,:after,:before{border:0 solid #e5e7eb;box-sizing:border-box}:after,:before{--tw-content:&quot;&quot;}html{-webkit-text-size-adjust:100%;font-feature-settings:normal;font-family:ui-sans-serif,system-ui,-apple-system,BlinkMacSystemFont,Segoe UI,Roboto,Helvetica Neue,Arial,Noto Sans,sans-serif,Apple Color Emoji,Segoe UI Emoji,Segoe UI Symbol,Noto Color Emoji;font-variation-settings:normal;line-height:1.5;-moz-tab-size:4;-o-tab-size:4;tab-size:4}body{line-height:inherit;margin:0}hr{border-top-width:1px;color:inherit;height:0}abbr:where([title]){-webkit-text-decoration:underline dotted;text-decoration:underline dotted}h1,h2,h3,h4,h5,h6{font-size:inherit;font-weight:inherit}a{color:inherit;text-decoration:inherit}b,strong{font-weight:bolder}code,kbd,pre,samp{font-family:ui-monospace,SFMono-Regular,Menlo,Monaco,Consolas,Liberation Mono,Courier New,monospace;font-size:1em}small{font-size:80%}sub,sup{font-size:75%;line-height:0;position:relative;vertical-align:baseline}sub{bottom:-.25em}sup{top:-.5em}table{border-collapse:collapse;border-color:inherit;text-indent:0}button,input,optgroup,select,textarea{color:inherit;font-family:inherit;font-size:100%;font-weight:inherit;line-height:inherit;margin:0;padding:0}button,select{text-transform:none}[type=button],[type=reset],[type=submit],button{-webkit-appearance:button;background-color:transparent;background-image:none}:-moz-focusring{outline:auto}:-moz-ui-invalid{box-shadow:none}progress{vertical-align:baseline}::-webkit-inner-spin-button,::-webkit-outer-spin-button{height:auto}[type=search]{-webkit-appearance:textfield;outline-offset:-2px}::-webkit-search-decoration{-webkit-appearance:none}::-webkit-file-upload-button{-webkit-appearance:button;font:inherit}summary{display:list-item}blockquote,dd,dl,figure,h1,h2,h3,h4,h5,h6,hr,p,pre{margin:0}fieldset{margin:0}fieldset,legend{padding:0}menu,ol,ul{list-style:none;margin:0;padding:0}textarea{resize:vertical}input::-moz-placeholder,textarea::-moz-placeholder{color:#9ca3af;opacity:1}input::placeholder,textarea::placeholder{color:#9ca3af;opacity:1}[role=button],button{cursor:pointer}:disabled{cursor:default}audio,canvas,embed,iframe,img,object,svg,video{display:block;vertical-align:middle}img,video{height:auto;max-width:100%}[hidden]{display:none}*,:after,:before{--tw-border-spacing-x:0;--tw-border-spacing-y:0;--tw-translate-x:0;--tw-translate-y:0;--tw-rotate:0;--tw-skew-x:0;--tw-skew-y:0;--tw-scale-x:1;--tw-scale-y:1;--tw-pan-x: ;--tw-pan-y: ;--tw-pinch-zoom: ;--tw-scroll-snap-strictness:proximity;--tw-gradient-from-position: ;--tw-gradient-via-position: ;--tw-gradient-to-position: ;--tw-ordinal: ;--tw-slashed-zero: ;--tw-numeric-figure: ;--tw-numeric-spacing: ;--tw-numeric-fraction: ;--tw-ring-inset: ;--tw-ring-offset-width:0px;--tw-ring-offset-color:#fff;--tw-ring-color:rgba(59,130,246,.5);--tw-ring-offset-shadow:0 0 #0000;--tw-ring-shadow:0 0 #0000;--tw-shadow:0 0 #0000;--tw-shadow-colored:0 0 #0000;--tw-blur: ;--tw-brightness: ;--tw-contrast: ;--tw-grayscale: ;--tw-hue-rotate: ;--tw-invert: ;--tw-saturate: ;--tw-sepia: ;--tw-drop-shadow: ;--tw-backdrop-blur: ;--tw-backdrop-brightness: ;--tw-backdrop-contrast: ;--tw-backdrop-grayscale: ;--tw-backdrop-hue-rotate: ;--tw-backdrop-invert: ;--tw-backdrop-opacity: ;--tw-backdrop-saturate: ;--tw-backdrop-sepia: }::backdrop{--tw-border-spacing-x:0;--tw-border-spacing-y:0;--tw-translate-x:0;--tw-translate-y:0;--tw-rotate:0;--tw-skew-x:0;--tw-skew-y:0;--tw-scale-x:1;--tw-scale-y:1;--tw-pan-x: ;--tw-pan-y: ;--tw-pinch-zoom: ;--tw-scroll-snap-strictness:proximity;--tw-gradient-from-position: ;--tw-gradient-via-position: ;--tw-gradient-to-position: ;--tw-ordinal: ;--tw-slashed-zero: ;--tw-numeric-figure: ;--tw-numeric-spacing: ;--tw-numeric-fraction: ;--tw-ring-inset: ;--tw-ring-offset-width:0px;--tw-ring-offset-color:#fff;--tw-ring-color:rgba(59,130,246,.5);--tw-ring-offset-shadow:0 0 #0000;--tw-ring-shadow:0 0 #0000;--tw-shadow:0 0 #0000 ...

# %%
display(scan_results)
# Out:
# <iframe id="scan-140556518214096" srcdoc="&lt;!doctype html&gt;
# &lt;html lang=&quot;en&quot;&gt;
#
# &lt;head&gt;
#     &lt;title&gt;Giskard Scan Results&lt;/title&gt;
#     &lt;base target=&quot;_blank&quot;&gt;
#     &lt;meta charset=&quot;utf-8&quot;&gt;
#
# &lt;style&gt;pre code.hljs{display:block;overflow-x:auto;padding:1em}code.hljs{padding:3px 5px}
# /*!
#   Theme: GitHub Dark
#   Description: Dark theme as seen on github.com
#   Author: github.com
#   Maintainer: @Hirse
#   Updated: 2021-05-15
#
#   Outdated base version: https://github.com/primer/github-syntax-dark
#   Current colors taken from GitHub&#x27;s CSS
# */.hljs{background:#0d1117;color:#c9d1d9}.hljs-doctag,.hljs-keyword,.hljs-meta .hljs-keyword,.hljs-template-tag,.hljs-template-variable,.hljs-type,.hljs-variable.language_{color:#ff7b72}.hljs-title,.hljs-title.class_,.hljs-title.class_.inherited__,.hljs-title.function_{color:#d2a8ff}.hljs-attr,.hljs-attribute,.hljs-literal,.hljs-meta,.hljs-number,.hljs-operator,.hljs-selector-attr,.hljs-selector-class,.hljs-selector-id,.hljs-variable{color:#79c0ff}.hljs-meta .hljs-string,.hljs-regexp,.hljs-string{color:#a5d6ff}.hljs-built_in,.hljs-symbol{color:#ffa657}.hljs-code,.hljs-comment,.hljs-formula{color:#8b949e}.hljs-name,.hljs-quote,.hljs-selector-pseudo,.hljs-selector-tag{color:#7ee787}.hljs-subst{color:#c9d1d9}.hljs-section{color:#1f6feb;font-weight:700}.hljs-bullet{color:#f2cc60}.hljs-emphasis{color:#c9d1d9;font-style:italic}.hljs-strong{color:#c9d1d9;font-weight:700}.hljs-addition{background-color:#033a16;color:#aff5b4}.hljs-deletion{background-color:#67060c;color:#ffdcd7}.hljs-copy-wrapper{overflow:hidden;position:relative}.hljs-copy-button:focus,.hljs-copy-wrapper:hover .hljs-copy-button{transform:translateX(0)}.hljs-copy-button{background-color:#2d2b57;background-color:var(--hljs-theme-background);background-image:url(&#x27;data:image/svg+xml;charset=utf-8,&lt;svg xmlns=&quot;http://www.w3.org/2000/svg&quot; width=&quot;16&quot; height=&quot;16&quot; fill=&quot;none&quot; viewBox=&quot;0 0 24 24&quot;&gt;&lt;path fill=&quot;%23fff&quot; fill-rule=&quot;evenodd&quot; d=&quot;M6 5a1 1 0 0 0-1 1v14a1 1 0 0 0 1 1h12a1 1 0 0 0 1-1V6a1 1 0 0 0-1-1h-2a1 1 0 1 1 0-2h2a3 3 0 0 1 3 3v14a3 3 0 0 1-3 3H6a3 3 0 0 1-3-3V6a3 3 0 0 1 3-3h2a1 1 0 0 1 0 2H6Z&quot; clip-rule=&quot;evenodd&quot;/&gt;&lt;path fill=&quot;%23fff&quot; fill-rule=&quot;evenodd&quot; d=&quot;M7 3a2 2 0 0 1 2-2h6a2 2 0 0 1 2 2v2a2 2 0 0 1-2 2H9a2 2 0 0 1-2-2V3Zm8 0H9v2h6V3Z&quot; clip-rule=&quot;evenodd&quot;/&gt;&lt;/svg&gt;&#x27;);background-position:50%;background-repeat:no-repeat;border:1px solid #ffffff22;border-radius:.25rem;color:#fff;height:2rem;position:absolute;right:1em;text-indent:-9999px;top:1em;transition:background-color .2s ease,transform .2s ease-out;width:2rem}.hljs-copy-button:hover{border-color:#ffffff44}.hljs-copy-button:active{border-color:#ffffff66}.hljs-copy-button[data-copied=true]{background-image:none;text-indent:0;width:auto}@media (prefers-reduced-motion){.hljs-copy-button{transition:none}}.hljs-copy-alert{clip:rect(0 0 0 0);-webkit-clip-path:inset(50%);clip-path:inset(50%);height:1px;overflow:hidden;position:absolute;white-space:nowrap;width:1px}
# /*! tailwindcss v3.3.2 | MIT License | https://tailwindcss.com*/*,:after,:before{border:0 solid #e5e7eb;box-sizing:border-box}:after,:before{--tw-content:&quot;&quot;}html{-webkit-text-size-adjust:100%;font-feature-settings:normal;font-family:ui-sans-serif,system-ui,-apple-system,BlinkMacSystemFont,Segoe UI,Roboto,Helvetica Neue,Arial,Noto Sans,sans-serif,Apple Color Emoji,Segoe UI Emoji,Segoe UI Symbol,Noto Color Emoji;font-variation-settings:normal;line-height:1.5;-moz-tab-size:4;-o-tab-size:4;tab-size:4}body{line-height:inherit;margin:0}hr{border-top-width:1px;color:inherit;height:0}abbr:where([title]){-webkit-text-decoration:underline dotted;text-decoration:underline dotted}h1,h2,h3,h4,h5,h6{font-size:inherit;font-weight:inherit}a{color:inherit;text-decoration:inherit}b,strong{font-weight:bolder}code,kbd,pre,samp{font-family:ui-monospace,SFMono-Regular,Menlo,Monaco,Consolas,Liberation Mono,Courier New,monospace;font-size:1em}small{font-size:80%}sub,sup{font-size:75%;line-height:0;position:relative;vertical-align:baseline}sub{bottom:-.25em}sup{top:-.5em}table{border-collapse:collapse;border-color:inherit;text-indent:0}button,input,optgroup,select,textarea{color:inherit;font-family:inherit;font-size:100%;font-weight:inherit;line-height:inherit;margin:0;padding:0}button,select{text-transform:none}[type=button],[type=reset],[type=submit],button{-webkit-appearance:button;background-color:transparent;background-image:none}:-moz-focusring{outline:auto}:-moz-ui-invalid{box-shadow:none}progress{vertical-align:baseline}::-webkit-inner-spin-button,::-webkit-outer-spin-button{height:auto}[type=search]{-webkit-appearance:textfield;outline-offset:-2px}::-webkit-search-decoration{-webkit-appearance:none}::-webkit-file-upload-button{-webkit-appearance:button;font:inherit}summary{display:list-item}blockquote,dd,dl,figure,h1,h2,h3,h4,h5,h6,hr,p,pre{margin:0}fieldset{margin:0}fieldset,legend{padding:0}menu,ol,ul{list-style:none;margin:0;padding:0}textarea{resize:vertical}input::-moz-placeholder,textarea::-moz-placeholder{color:#9ca3af;opacity:1}input::placeholder,textarea::placeholder{color:#9ca3af;opacity:1}[role=button],button{cursor:pointer}:disabled{cursor:default}audio,canvas,embed,iframe,img,object,svg,video{display:block;vertical-align:middle}img,video{height:auto;max-width:100%}[hidden]{display:none}*,:after,:before{--tw-border-spacing-x:0;--tw-border-spacing-y:0;--tw-translate-x:0;--tw-translate-y:0;--tw-rotate:0;--tw-skew-x:0;--tw-skew-y:0;--tw-scale-x:1;--tw-scale-y:1;--tw-pan-x: ;--tw-pan-y: ;--tw-pinch-zoom: ;--tw-scroll-snap-strictness:proximity;--tw-gradient-from-position: ;--tw-gradient-via-position: ;--tw-gradient-to-position: ;--tw-ordinal: ;--tw-slashed-zero: ;--tw-numeric-figure: ;--tw-numeric-spacing: ;--tw-numeric-fraction: ;--tw-ring-inset: ;--tw-ring-offset-width:0px;--tw-ring-offset-color:#fff;--tw-ring-color:rgba(59,130,246,.5);--tw-ring-offset-shadow:0 0 #0000;--tw-ring-shadow:0 0 #0000;--tw-shadow:0 0 #0000;--tw-shadow-colored:0 0 #0000;--tw-blur: ;--tw-brightness: ;--tw-contrast: ;--tw-grayscale: ;--tw-hue-rotate: ;--tw-invert: ;--tw-saturate: ;--tw-sepia: ;--tw-drop-shadow: ;--tw-backdrop-blur: ;--tw-backdrop-brightness: ;--tw-backdrop-contrast: ;--tw-backdrop-grayscale: ;--tw-backdrop-hue-rotate: ;--tw-backdrop-invert: ;--tw-backdrop-opacity: ;--tw-backdrop-saturate: ;--tw-backdrop-sepia: }::backdrop{--tw-border-spacing-x:0;--tw-border-spacing-y:0;--tw-translate-x:0;--tw-translate-y:0;--tw-rotate:0;--tw-skew-x:0;--tw-skew-y:0;--tw-scale-x:1;--tw-scale-y:1;--tw-pan-x: ;--tw-pan-y: ;--tw-pinch-zoom: ;--tw-scroll-snap-strictness:proximity;--tw-gradient-from-position: ;--tw-gradient-via-position: ;--tw-gradient-to-position: ;--tw-ordinal: ;--tw-slashed-zero: ;--tw-numeric-figure: ;--tw-numeric-spacing: ;--tw-numeric-fraction: ;--tw-ring-inset: ;--tw-ring-offset-width:0px;--tw-ring-offset-color:#fff;--tw-ring-color:rgba(59,130,246,.5);--tw-ring-offset-shadow:0 0 #0000;--tw-ring-shadow:0 0 #0000;--tw-shadow:0 0 #0000 ...

# %% [markdown]
# We have only a few issues. Perfect. We have performance problems in some segments, containing words like "small" or "bathroom". Fixing such issues is often not straightforward, however, and generally requires more data, or data augmentation with e.g. [nlpaug](https://github.com/makcedward/nlpaug) library. Typically, fixing many of these issues is quite hard, but just being aware of them can be useful.

# %% [markdown]
# # Interpretability
# Interpretability is a fundamental aspect of developing trustworthy and effective AI systems, particularly when decisions made by these systems have significant implications. It involves understanding and explaining how AI models make their decisions, which is crucial for gaining user trust, fulfilling regulatory requirements, and facilitating model debugging and improvement. It bridges the gap between advanced computational models and human understanding, ensuring that AI systems are not only powerful and efficient but also aligned with ethical standards and user expectations.

# %% [markdown]
# ## Global vs local explainability
#
# Understanding the overall behavior of the model is known as **global explainability**, and is generally tough. Modern NLP models are incredibly complex and basically impossible to summarize like "if description mentions small room, then predict negative sentiment". This is also less interesting to end users, who are often interested in understanding prediction for a single given text, known as **local interpretability**.
#
# There are a lot of techniques for this, benchmarked in papers:
# - ["A Diagnostic Study of Explainability Techniques for Text Classification" P. Atanasova et al.](https://aclanthology.org/2020.emnlp-main.263/)
# - ["A Multilingual Perspective Towards the Evaluation of Attribution Methods in Natural Language Inference" K. Zaman, Y. Belinkov](https://aclanthology.org/2022.emnlp-main.101/)
#
# Interestingly, both papers and our practical experience show that the simplest **gradient attribution** methods perform the best. They are fast, faithful to the inner workings of the model, and make sense for human evaluators. Concretely, InputXGradient method with either mean or L2 normalization per word gives the best results. In short, it works as follows:
# 1. Compute model prediction with gradients, just like during training, but without updating model weights.
# 2. With backpropagation, compute gradient for each input token, also known as saliency or **attribution**.
# 3. Multiply tokens by their gradient (hence the name), getting token attribution vector.
# 4. Normalize attribution, i.e., calculate either average or L2-normalized score for each word.
#
# This way, we get a single number per token. Gradients are computed for a given class. For binary classification, we predict the probability of positive class. Therefore, higher scores indicate that tokens increase the probability, and negative scores mean that they decrease probability.
#
# Why does this simple method work very well? We don't really know. There are some hypotheses, but they are of high mathematical complexity. If you're interested, see e.g. ["The Manifold Hypothesis for Gradient-Based Explanations" S. Bordt et al](https://openaccess.thecvf.com/content/CVPR2023W/XAI4CV/papers/Bordt_The_Manifold_Hypothesis_for_Gradient-Based_Explanations_CVPRW_2023_paper.pdf). A major advantage is also speed. This requires computing gradients, but it's still just one forward and backward pass through the model. Other methods are much more complex, like SHAP for text, which has almost exponential complexity.

# %% [markdown]
# ## Local explainability with Captum
#
# [Captum](https://captum.ai/) is the most popular model interpretability library for PyTorch. It works for computer vision, NLP, [LLMs](https://captum.ai/tutorials/Llama2_LLM_Attribution) and other models. While the most important part are model attributions, which we will use to understand inputs, Captum also supports adversarial attacks, neuron and layer explanations, and identifying influential examples.
#
# The code below is modified from [Captum question answering tutorial](https://captum.ai/tutorials/Bert_SQUAD_Interpret). Firstly, we tokenize texts. The essential part is calling the `configure_interpretable_embedding_layer()` function - this special embedding layer replaces the existing transformer embedding layer with Captum one, which tracks gradients and combines explanations with original tokens. Furthermore, since Captum requires gradients, we need to make a small wrapper to pass `attention_mask` to our transformer. Lastly, we make the overall model prediction and use built-in visualization methods to plot the results.

# %%
from copy import deepcopy

from captum.attr import InputXGradient, configure_interpretable_embedding_layer
from captum.attr import visualization as vis


class BERTModelWrapper(torch.nn.Module):
    def __init__(self, model):
        super().__init__()
        self.model = model

    def forward(self, inputs, attention_mask):
        return self.model(inputs, attention_mask=attention_mask)[0]


def explain_text(model, text: str, y_true: int) -> None:
    # make sure we compute gradients as necessary
    for param in model.distilbert.parameters():
        param.requires_grad = True
    
    tokenizer_output = tokenizer.encode_plus(
        text,
        add_special_tokens=True,
        return_attention_mask=True,
        return_tensors="pt",
    )
    
    device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
    tokenizer_output = tokenizer_output.to(device)
    tokens = tokenizer.convert_ids_to_tokens(tokenizer_output["input_ids"][0])

    model_copy = deepcopy(model)
    interpretable_embedding_layer = configure_interpretable_embedding_layer(
        model_copy, "distilbert.embeddings"
    )
    input_embeddings = interpretable_embedding_layer.indices_to_embeddings(
        tokenizer_output["input_ids"]
    )

    model_wrapper = BERTModelWrapper(model_copy)
    input_x_gradient = InputXGradient(model_wrapper)
    attributions = input_x_gradient.attribute(
        input_embeddings,
        target=1,
        additional_forward_args=tokenizer_output["attention_mask"],
    )

    # mean normalization
    attributions = attributions.sum(dim=-1).squeeze(0)
    attributions = attributions / torch.norm(attributions)
    attributions = list([float(attr) for attr in attributions])
    
    with torch.no_grad():
        logits = model(**tokenizer_output).logits
        y_pred_proba = softmax(logits, dim=1)[0, 1].item()
        y_pred = int(y_pred_proba >= 0.5)

    # remove [CLS] and [SEP] tokens
    attributions = attributions[1:-1]
    tokens = tokens[1:-1]
    
    vis_record = vis.VisualizationDataRecord(
        word_attributions=attributions,
        pred_prob=y_pred_proba,
        pred_class=y_pred,
        true_class=y_true,
        attr_class=1,
        attr_score=sum(attributions),
        raw_input_ids=tokens,
        convergence_score=0,
    )
    vis.visualize_text([vis_record])

# %% [markdown]
# ### Exercise 5 (1 point)
#
# 1. Use Captum and implemented function to explain predictions for the first 3 positive and 3 negative samples from the test set.
# 2. Comment, do you think that results make sense? Does the model focus on reasonable words, both for positive and negative sentiment?

# %%
test_sample_1, test_sample_2, test_sample_3 = df_test[df_test["label"] == 1].head(3)["text"].values

# %%
explain_text(trained_model, test_sample_1, y_true=1)
# Out:
# <table width: 100%><div style="border-top: 1px solid; margin-top: 5px;             padding-top: 5px; display: inline-block"><b>Legend: </b><span style="display: inline-block; width: 10px; height: 10px;                 border: 1px solid; background-color:                 hsl(0, 75%, 60%)"></span> Negative  <span style="display: inline-block; width: 10px; height: 10px;                 border: 1px solid; background-color:                 hsl(0, 75%, 100%)"></span> Neutral  <span style="display: inline-block; width: 10px; height: 10px;                 border: 1px solid; background-color:                 hsl(120, 75%, 50%)"></span> Positive  </div><tr><th>True Label</th><th>Predicted Label</th><th>Attribution Label</th><th>Attribution Score</th><th>Word Importance</th><tr><td><text style="padding-right:2em"><b>1</b></text></td><td><text style="padding-right:2em"><b>1 (1.00)</b></text></td><td><text style="padding-right:2em"><b>1</b></text></td><td><text style="padding-right:2em"><b>0.86</b></text></td><td><mark style="background-color: hsl(120, 75%, 84%); opacity:1.0;                     line-height:1.75"><font color="black"> staff                    </font></mark><mark style="background-color: hsl(0, 75%, 97%); opacity:1.0;                     line-height:1.75"><font color="black"> at                    </font></mark><mark style="background-color: hsl(0, 75%, 91%); opacity:1.0;                     line-height:1.75"><font color="black"> front                    </font></mark><mark style="background-color: hsl(0, 75%, 96%); opacity:1.0;                     line-height:1.75"><font color="black"> desk                    </font></mark><mark style="background-color: hsl(120, 75%, 100%); opacity:1.0;                     line-height:1.75"><font color="black"> was                    </font></mark><mark style="background-color: hsl(120, 75%, 89%); opacity:1.0;                     line-height:1.75"><font color="black"> extremely                    </font></mark><mark style="background-color: hsl(120, 75%, 91%); opacity:1.0;                     line-height:1.75"><font color="black"> helpful                    </font></mark><mark style="background-color: hsl(120, 75%, 87%); opacity:1.0;                     line-height:1.75"><font color="black"> and                    </font></mark><mark style="background-color: hsl(120, 75%, 87%); opacity:1.0;                     line-height:1.75"><font color="black"> friendly                    </font></mark></td><tr></table>

# %%
explain_text(trained_model, test_sample_2, y_true=1)
# Out:
# <table width: 100%><div style="border-top: 1px solid; margin-top: 5px;             padding-top: 5px; display: inline-block"><b>Legend: </b><span style="display: inline-block; width: 10px; height: 10px;                 border: 1px solid; background-color:                 hsl(0, 75%, 60%)"></span> Negative  <span style="display: inline-block; width: 10px; height: 10px;                 border: 1px solid; background-color:                 hsl(0, 75%, 100%)"></span> Neutral  <span style="display: inline-block; width: 10px; height: 10px;                 border: 1px solid; background-color:                 hsl(120, 75%, 50%)"></span> Positive  </div><tr><th>True Label</th><th>Predicted Label</th><th>Attribution Label</th><th>Attribution Score</th><th>Word Importance</th><tr><td><text style="padding-right:2em"><b>1</b></text></td><td><text style="padding-right:2em"><b>1 (1.00)</b></text></td><td><text style="padding-right:2em"><b>1</b></text></td><td><text style="padding-right:2em"><b>-0.13</b></text></td><td><mark style="background-color: hsl(0, 75%, 97%); opacity:1.0;                     line-height:1.75"><font color="black"> location                    </font></mark><mark style="background-color: hsl(120, 75%, 100%); opacity:1.0;                     line-height:1.75"><font color="black"> friendly                    </font></mark><mark style="background-color: hsl(120, 75%, 80%); opacity:1.0;                     line-height:1.75"><font color="black"> staff                    </font></mark><mark style="background-color: hsl(120, 75%, 90%); opacity:1.0;                     line-height:1.75"><font color="black"> helpful                    </font></mark><mark style="background-color: hsl(120, 75%, 96%); opacity:1.0;                     line-height:1.75"><font color="black"> excellent                    </font></mark><mark style="background-color: hsl(0, 75%, 90%); opacity:1.0;                     line-height:1.75"><font color="black"> food                    </font></mark><mark style="background-color: hsl(0, 75%, 96%); opacity:1.0;                     line-height:1.75"><font color="black"> at                    </font></mark><mark style="background-color: hsl(0, 75%, 70%); opacity:1.0;                     line-height:1.75"><font color="black"> the                    </font></mark><mark style="background-color: hsl(120, 75%, 96%); opacity:1.0;                     line-height:1.75"><font color="black"> restaurant                    </font></mark><mark style="background-color: hsl(120, 75%, 99%); opacity:1.0;                     line-height:1.75"><font color="black"> very                    </font></mark><mark style="background-color: hsl(120, 75%, 96%); opacity:1.0;                     line-height:1.75"><font color="black"> good                    </font></mark><mark style="background-color: hsl(0, 75%, 100%); opacity:1.0;                     line-height:1.75"><font color="black"> breakfast                    </font></mark><mark style="background-color: hsl(120, 75%, 99%); opacity:1.0;                     line-height:1.75"><font color="black"> feel                    </font></mark><mark style="background-color: hsl(120, 75%, 93%); opacity:1.0;                     line-height:1.75"><font color="black"> home                    </font></mark></td><tr></table>

# %%
explain_text(trained_model, test_sample_3, y_true=1)
# Out:
# <table width: 100%><div style="border-top: 1px solid; margin-top: 5px;             padding-top: 5px; display: inline-block"><b>Legend: </b><span style="display: inline-block; width: 10px; height: 10px;                 border: 1px solid; background-color:                 hsl(0, 75%, 60%)"></span> Negative  <span style="display: inline-block; width: 10px; height: 10px;                 border: 1px solid; background-color:                 hsl(0, 75%, 100%)"></span> Neutral  <span style="display: inline-block; width: 10px; height: 10px;                 border: 1px solid; background-color:                 hsl(120, 75%, 50%)"></span> Positive  </div><tr><th>True Label</th><th>Predicted Label</th><th>Attribution Label</th><th>Attribution Score</th><th>Word Importance</th><tr><td><text style="padding-right:2em"><b>1</b></text></td><td><text style="padding-right:2em"><b>1 (1.00)</b></text></td><td><text style="padding-right:2em"><b>1</b></text></td><td><text style="padding-right:2em"><b>0.15</b></text></td><td><mark style="background-color: hsl(120, 75%, 100%); opacity:1.0;                     line-height:1.75"><font color="black"> the                    </font></mark><mark style="background-color: hsl(120, 75%, 98%); opacity:1.0;                     line-height:1.75"><font color="black"> staff                    </font></mark><mark style="background-color: hsl(0, 75%, 99%); opacity:1.0;                     line-height:1.75"><font color="black"> were                    </font></mark><mark style="background-color: hsl(120, 75%, 99%); opacity:1.0;                     line-height:1.75"><font color="black"> friendly                    </font></mark><mark style="background-color: hsl(0, 75%, 97%); opacity:1.0;                     line-height:1.75"><font color="black"> and                    </font></mark><mark style="background-color: hsl(120, 75%, 97%); opacity:1.0;                     line-height:1.75"><font color="black"> helpful                    </font></mark><mark style="background-color: hsl(0, 75%, 96%); opacity:1.0;                     line-height:1.75"><font color="black"> the                    </font></mark><mark style="background-color: hsl(0, 75%, 100%); opacity:1.0;                     line-height:1.75"><font color="black"> bed                    </font></mark><mark style="background-color: hsl(0, 75%, 98%); opacity:1.0;                     line-height:1.75"><font color="black"> was                    </font></mark><mark style="background-color: hsl(120, 75%, 95%); opacity:1.0;                     line-height:1.75"><font color="black"> comfortable                    </font></mark><mark style="background-color: hsl(0, 75%, 99%); opacity:1.0;                     line-height:1.75"><font color="black"> the                    </font></mark><mark style="background-color: hsl(120, 75%, 99%); opacity:1.0;                     line-height:1.75"><font color="black"> room                    </font></mark><mark style="background-color: hsl(0, 75%, 99%); opacity:1.0;                     line-height:1.75"><font color="black"> was                    </font></mark><mark style="background-color: hsl(120, 75%, 100%); opacity:1.0;                     line-height:1.75"><font color="black"> quiet                    </font></mark><mark style="background-color: hsl(120, 75%, 99%); opacity:1.0;                     line-height:1.75"><font color="black"> and                    </font></mark><mark style="background-color: hsl(120, 75%, 96%); opacity:1.0;                     line-height:1.75"><font color="black"> nicely                    </font></mark><mark style="background-color: hsl(120, 75%, 94%); opacity:1.0;                     line-height:1.75"><font color="black"> furnished                    </font></mark><mark style="background-color: hsl(0, 75%, 93%); opacity:1.0;                     line-height:1.75"><font color="black"> the                    </font></mark><mark style="background-color: hsl(0, 75%, 100%); opacity:1.0;                     li ...

# %%
test_sample_n_1, test_sample_n_2, test_sample_n_3 = df_test[df_test["label"] == 0].head(3)["text"].values

# %%
explain_text(trained_model, test_sample_n_1, y_true=0)
# Out:
# <table width: 100%><div style="border-top: 1px solid; margin-top: 5px;             padding-top: 5px; display: inline-block"><b>Legend: </b><span style="display: inline-block; width: 10px; height: 10px;                 border: 1px solid; background-color:                 hsl(0, 75%, 60%)"></span> Negative  <span style="display: inline-block; width: 10px; height: 10px;                 border: 1px solid; background-color:                 hsl(0, 75%, 100%)"></span> Neutral  <span style="display: inline-block; width: 10px; height: 10px;                 border: 1px solid; background-color:                 hsl(120, 75%, 50%)"></span> Positive  </div><tr><th>True Label</th><th>Predicted Label</th><th>Attribution Label</th><th>Attribution Score</th><th>Word Importance</th><tr><td><text style="padding-right:2em"><b>0</b></text></td><td><text style="padding-right:2em"><b>0 (0.01)</b></text></td><td><text style="padding-right:2em"><b>1</b></text></td><td><text style="padding-right:2em"><b>-0.24</b></text></td><td><mark style="background-color: hsl(120, 75%, 90%); opacity:1.0;                     line-height:1.75"><font color="black"> the                    </font></mark><mark style="background-color: hsl(0, 75%, 93%); opacity:1.0;                     line-height:1.75"><font color="black"> bill                    </font></mark><mark style="background-color: hsl(120, 75%, 93%); opacity:1.0;                     line-height:1.75"><font color="black"> had                    </font></mark><mark style="background-color: hsl(120, 75%, 84%); opacity:1.0;                     line-height:1.75"><font color="black"> been                    </font></mark><mark style="background-color: hsl(0, 75%, 100%); opacity:1.0;                     line-height:1.75"><font color="black"> split                    </font></mark><mark style="background-color: hsl(0, 75%, 94%); opacity:1.0;                     line-height:1.75"><font color="black"> per                    </font></mark><mark style="background-color: hsl(120, 75%, 89%); opacity:1.0;                     line-height:1.75"><font color="black"> room                    </font></mark><mark style="background-color: hsl(120, 75%, 97%); opacity:1.0;                     line-height:1.75"><font color="black"> when                    </font></mark><mark style="background-color: hsl(0, 75%, 95%); opacity:1.0;                     line-height:1.75"><font color="black"> i                    </font></mark><mark style="background-color: hsl(0, 75%, 95%); opacity:1.0;                     line-height:1.75"><font color="black"> booked                    </font></mark><mark style="background-color: hsl(0, 75%, 99%); opacity:1.0;                     line-height:1.75"><font color="black"> as                    </font></mark><mark style="background-color: hsl(120, 75%, 95%); opacity:1.0;                     line-height:1.75"><font color="black"> a                    </font></mark><mark style="background-color: hsl(120, 75%, 94%); opacity:1.0;                     line-height:1.75"><font color="black"> group                    </font></mark><mark style="background-color: hsl(0, 75%, 99%); opacity:1.0;                     line-height:1.75"><font color="black"> under                    </font></mark><mark style="background-color: hsl(0, 75%, 92%); opacity:1.0;                     line-height:1.75"><font color="black"> 1                    </font></mark><mark style="background-color: hsl(0, 75%, 78%); opacity:1.0;                     line-height:1.75"><font color="black"> bill                    </font></mark></td><tr></table>

# %%
explain_text(trained_model, test_sample_n_2, y_true=0)
# Out:
# <table width: 100%><div style="border-top: 1px solid; margin-top: 5px;             padding-top: 5px; display: inline-block"><b>Legend: </b><span style="display: inline-block; width: 10px; height: 10px;                 border: 1px solid; background-color:                 hsl(0, 75%, 60%)"></span> Negative  <span style="display: inline-block; width: 10px; height: 10px;                 border: 1px solid; background-color:                 hsl(0, 75%, 100%)"></span> Neutral  <span style="display: inline-block; width: 10px; height: 10px;                 border: 1px solid; background-color:                 hsl(120, 75%, 50%)"></span> Positive  </div><tr><th>True Label</th><th>Predicted Label</th><th>Attribution Label</th><th>Attribution Score</th><th>Word Importance</th><tr><td><text style="padding-right:2em"><b>0</b></text></td><td><text style="padding-right:2em"><b>0 (0.01)</b></text></td><td><text style="padding-right:2em"><b>1</b></text></td><td><text style="padding-right:2em"><b>-0.13</b></text></td><td><mark style="background-color: hsl(0, 75%, 94%); opacity:1.0;                     line-height:1.75"><font color="black"> would                    </font></mark><mark style="background-color: hsl(120, 75%, 93%); opacity:1.0;                     line-height:1.75"><font color="black"> be                    </font></mark><mark style="background-color: hsl(120, 75%, 100%); opacity:1.0;                     line-height:1.75"><font color="black"> better                    </font></mark><mark style="background-color: hsl(120, 75%, 96%); opacity:1.0;                     line-height:1.75"><font color="black"> have                    </font></mark><mark style="background-color: hsl(120, 75%, 93%); opacity:1.0;                     line-height:1.75"><font color="black"> a                    </font></mark><mark style="background-color: hsl(120, 75%, 100%); opacity:1.0;                     line-height:1.75"><font color="black"> separated                    </font></mark><mark style="background-color: hsl(120, 75%, 99%); opacity:1.0;                     line-height:1.75"><font color="black"> shower                    </font></mark><mark style="background-color: hsl(0, 75%, 96%); opacity:1.0;                     line-height:1.75"><font color="black"> bath                    </font></mark><mark style="background-color: hsl(120, 75%, 64%); opacity:1.0;                     line-height:1.75"><font color="black"> facility                    </font></mark><mark style="background-color: hsl(0, 75%, 93%); opacity:1.0;                     line-height:1.75"><font color="black"> is                    </font></mark><mark style="background-color: hsl(0, 75%, 93%); opacity:1.0;                     line-height:1.75"><font color="black"> a                    </font></mark><mark style="background-color: hsl(0, 75%, 86%); opacity:1.0;                     line-height:1.75"><font color="black"> bit                    </font></mark><mark style="background-color: hsl(0, 75%, 89%); opacity:1.0;                     line-height:1.75"><font color="black"> defective                    </font></mark></td><tr></table>

# %%
explain_text(trained_model, test_sample_n_3, y_true=0)
# Out:
# <table width: 100%><div style="border-top: 1px solid; margin-top: 5px;             padding-top: 5px; display: inline-block"><b>Legend: </b><span style="display: inline-block; width: 10px; height: 10px;                 border: 1px solid; background-color:                 hsl(0, 75%, 60%)"></span> Negative  <span style="display: inline-block; width: 10px; height: 10px;                 border: 1px solid; background-color:                 hsl(0, 75%, 100%)"></span> Neutral  <span style="display: inline-block; width: 10px; height: 10px;                 border: 1px solid; background-color:                 hsl(120, 75%, 50%)"></span> Positive  </div><tr><th>True Label</th><th>Predicted Label</th><th>Attribution Label</th><th>Attribution Score</th><th>Word Importance</th><tr><td><text style="padding-right:2em"><b>0</b></text></td><td><text style="padding-right:2em"><b>0 (0.00)</b></text></td><td><text style="padding-right:2em"><b>1</b></text></td><td><text style="padding-right:2em"><b>-2.06</b></text></td><td><mark style="background-color: hsl(0, 75%, 100%); opacity:1.0;                     line-height:1.75"><font color="black"> don                    </font></mark><mark style="background-color: hsl(120, 75%, 100%); opacity:1.0;                     line-height:1.75"><font color="black"> t                    </font></mark><mark style="background-color: hsl(120, 75%, 98%); opacity:1.0;                     line-height:1.75"><font color="black"> order                    </font></mark><mark style="background-color: hsl(120, 75%, 95%); opacity:1.0;                     line-height:1.75"><font color="black"> a                    </font></mark><mark style="background-color: hsl(0, 75%, 87%); opacity:1.0;                     line-height:1.75"><font color="black"> taxi                    </font></mark><mark style="background-color: hsl(120, 75%, 92%); opacity:1.0;                     line-height:1.75"><font color="black"> it                    </font></mark><mark style="background-color: hsl(0, 75%, 91%); opacity:1.0;                     line-height:1.75"><font color="black"> costs                    </font></mark><mark style="background-color: hsl(120, 75%, 99%); opacity:1.0;                     line-height:1.75"><font color="black"> you                    </font></mark><mark style="background-color: hsl(120, 75%, 100%); opacity:1.0;                     line-height:1.75"><font color="black"> more                    </font></mark><mark style="background-color: hsl(0, 75%, 98%); opacity:1.0;                     line-height:1.75"><font color="black"> than                    </font></mark><mark style="background-color: hsl(0, 75%, 98%); opacity:1.0;                     line-height:1.75"><font color="black"> if                    </font></mark><mark style="background-color: hsl(120, 75%, 99%); opacity:1.0;                     line-height:1.75"><font color="black"> you                    </font></mark><mark style="background-color: hsl(120, 75%, 100%); opacity:1.0;                     line-height:1.75"><font color="black"> go                    </font></mark><mark style="background-color: hsl(0, 75%, 94%); opacity:1.0;                     line-height:1.75"><font color="black"> and                    </font></mark><mark style="background-color: hsl(120, 75%, 97%); opacity:1.0;                     line-height:1.75"><font color="black"> hail                    </font></mark><mark style="background-color: hsl(0, 75%, 100%); opacity:1.0;                     line-height:1.75"><font color="black"> one                    </font></mark><mark style="background-color: hsl(0, 75%, 95%); opacity:1.0;                     line-height:1.75"><font color="black"> from                    </font></mark><mark style="background-color: hsl(120, 75%, 97%); opacity:1.0;                     line-height:1.75"><font color="black"> street                    </font></mark><mark style="background-color: hsl(120, 75%, 95%); opacity:1.0;                     line-height:1.75"><font c ...

# %% [markdown]
# e// comment here

# %% [markdown]
# For me, only the first positive example makes sense. The model focuses on word "extremely helpful and friendly" which is clearly positive. In the second positive example, the attribution is negative because "the" gets huge negative value which shouldn't happen. This can be seen also in the third example, where "the" also gets negative attribution. However, words like "comfortable", "nicely furnished", "delicious" do get positive attribution, which is good.
